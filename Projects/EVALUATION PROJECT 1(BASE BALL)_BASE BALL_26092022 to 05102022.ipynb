# %% [markdown]
# # EXECUTIVE SUMMARY
#
# 1. Optimum Machine Model Chosen: LINEAR REGRESSION
#
# 2. Accuracy(r2) Score: 93%
#
# 3. Differential between Accuracy & CV Score: 1.13
#
# 4. RMSE:2.37
#
# 6. Key Operations executed: Exploratory Data Analysis(EDA), Data Preprocessing(Univariate,Bivariate,Multivariate), Metrics Measurement, Model Execution

# %% [markdown]
# # PROJECT CONTENTS
# - Problem Statement
# - Domain Knowledge
# - Step 1: Attributes of Variables
# - Step 2: IMPORT ALL NECESSARY LIBRARIES, LOAD DATA SET, DATA DESCRIPTIVE ANALYSIS AND OBSERVATIONS
#      - 2.1:Import all necessary libraries
#      - 2.2:Load Dataset
#      - 2.3:Data Descriptive Analysis
#      - 2.4:Observations
# - Step 3: EXPLORATORY DATA ANALYSIS
#      - 3.1:Normal Distribution Check(Univariate Analysis)
#      - 3.2:Scatter Plot Check(Bivariate Analysis)
#      - 3.3:Correlation Check(Collinearity and Multicollinearity)- Multivariate Analysis
#      - 3.4:Outlier Check
#      - 3.5:Skewness Check
# - Step 4: DATA PREPROCESSING
#      - 4.1:Removal of Duplicates and Unwanted Column
#      - 4.2:Dropping of Features that strongly promotes multicollinearity(VIF)
#      - 4.3:Removal of Outliers
#      - 4.4:Transforming Data to Remove Skewness using Power transformation
#      - 4.5:Seperating the datasets into X and Y variables
# - Step 5: MODEL BUILDING
#      - 5.1:Linear Regression
#      - 5.2:Decision Tree Regressor
#      - 5.3:RandomForest Regressor
#      - 5.4:AdaBoost Regressor
#      - 5.5:GradientBoosting Regressor
#      - 5.6:XGBoost Regressor
#      - 5.7:ExtraTrees Regressor
# - Step 6:COMPARING ALL MACHINE LEARNING MODELS
#      - 6.1:Creating a Dataframe for Accuracy Comparison
#      - 6.2:Comparing Differences between Accuracy and Cross_Validation Scores...
#      - 6.3:Conclusion on Best Choice of Model
# - Step 7:HYPERPARAMETER TUNNING
# - Step 8:MODEL SAVING

# %% [markdown]
# # PROBLEM STATEMENT(BASE BALL)
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.
#
# Downlaod Files:
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %% [markdown]
# # Domain Knowledge
# Before we proceed, its expedient to brainstorm and come up with as many hypothesis as possible about what could affect the dependent variable. It facilitates in exploring the data at hand more efficiently and effectively. Domain Knowledge should be done before seeing the data or else we will end up with biased hypotheses. Below are some anticipated assertions on the problem statement.
#
# - Offensive statistics have the most impact on win percentage.
#
# - Defensive statistics have the most impact on win percentage.

# %% [markdown]
# # Step 1 - ATTRIBUTES OF VARIABLES
# Lets understandthe meaning of the acronyms and their characteristics:
#
# 1. W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took        the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
#
# 2. R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely        to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely        on batted balls are met or assured: number of times a player crosses home plate.
#
#
# 3. AB - This meanse At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including           bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
#
# 4. H -  This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first           base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching         base because of a batted, fair ball without error by the defense.
#
#
# 5. 2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the         umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A         double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or             "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
#
# 6. 3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the             benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a           "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a             fielding error.
#
#
# 7. HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and             reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually             achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the           ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a             fielding error.
#
#
# 8. BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the             umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging           at four pitches called out of the strike zone and awarded first base.
#
#
# 9. SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually         means that the batter is out: number of batters who received strike three.
#
#
# 10. SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official              scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner            while the ball is in the possession of the defense.
#
#
# 11. RA - This means Run Average. It referes to measures of the rate at which runs are allowed or scored.
#
#
# 12. ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of            competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
#
# 13. ERA - This means Earned Run Average. It referes to the average of earned runs allowed by a pitcher per nine innings pitched           (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number           of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by           innings pitched.
#
#
# 14. CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A          pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played:              number of games where player was the only pitcher for their team.
#
#
# 15. SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the               opposing team to score a run: number of complete games pitched with no runs allowed.
#
#
# 16. SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed                    circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without              surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher              entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more          innings.
#
#
# 17. E -  This means Errors.It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that          allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter            should have been put out. The term error is sometimes used to refer to the play during which an error was committed:            number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a            result.

# %% [markdown]
# # Step 2 - IMPORT ALL NECESSARY LIBRARIES, LOAD DATA SET, DATA DESCRIPTIVE ANALYSIS AND OBSERVATIONS

# %% [markdown]
# # Step 2.1 - Import all necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler,power_transform,PowerTransformer,LabelEncoder
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV, RandomizedSearchCV
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report, plot_roc_curve,mean_squared_error,mean_absolute_error
from scipy.stats import zscore
import statsmodels.api as sm
from collections import Counter
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
import pickle


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2.2 - Load Dataset

# %%
#Load dataset
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
#checking the first five rows
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#checking the last five rows
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#picking 4 random samples
df.sample(4)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER   ERA  CG  SHO  \
# 13  76  656  5544  1379  262  22  198  478  1336  69  726  677  4.16   6   12
# 20  90  683  5527  1351  295  17  177  488  1290  51  613  557  3.43   1   14
# 8   80  644  5485  1383  278  32  167  436  1310  87  642  604  3.74   1   12
# 7   81  713  5485  1370  246  20  217  418  1331  44  693  646  4.05   0   10
#
#     SV   E
# 13  45  94
# 20  50  88
# 8   60  95
# 7   43  77

# %% [markdown]
# # Step 2.3 - Data Descriptive Analysis

# %%
#checking the data shape
df.shape
# Out:
# (30, 17)

# %%
#checking for nature of datatypes
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#Checking data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Checking data full description
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
#lets check the columns
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#Checking for null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Hmmm....the above shows there exist no null values meaning our data is deviod of emptyness! Hence there wont be any need to fill-up(fillna) any spaces!

# %%
#Checking for null values
df.isnull().sum().sum()
# Out:
# 0

# %%
#Checking the factors of each columns using a for loop for ease
for i in df.columns:
    print("\nThe Value Counts in", i, Counter(df[i]))
# Out:
# The Value Counts in W Counter({68: 3, 83: 2, 81: 2, 76: 2, 74: 2, 95: 1, 93: 1, 87: 1, 80: 1, 78: 1, 88: 1, 86: 1, 85: 1, 100: 1, 98: 1, 97: 1, 64: 1, 90: 1, 71: 1, 67: 1, 63: 1, 92: 1, 84: 1, 79: 1})
#
# The Value Counts in R Counter({696: 2, 689: 2, 724: 1, 669: 1, 622: 1, 891: 1, 764: 1, 713: 1, 644: 1, 748: 1, 751: 1, 729: 1, 661: 1, 656: 1, 694: 1, 647: 1, 697: 1, 655: 1, 640: 1, 683: 1, 703: 1, 613: 1, 573: 1, 626: 1, 667: 1, 720: 1, 650: 1, 737: 1})
#
# The Value Counts in AB Counter({5485: 2, 5575: 1, 5467: 1, 5439: 1, 5533: 1, 5605: 1, 5509: 1, 5567: 1, 5640: 1, 5511: 1, 5459: 1, 5417: 1, 5544: 1, 5600: 1, 5484: 1, 5631: 1, 5491: 1, 5480: 1, 5571: 1, 5527: 1, 5428: 1, 5463: 1, 5420: 1, 5529: 1, 5385: 1, 5565: 1, 5649: 1, 5457: 1, 5572: 1})
# The Value Counts in ER Counter({601: 1, 653: 1, 584: 1, 643: 1, 746: 1, 609: 1, 652: 1, 646: 1, 604: 1, 694: 1, 680: 1, 572: 1, 630: 1, 677: 1, 664: 1, 478: 1, 532: 1, 546: 1, 682: 1, 700: 1, 557: 1, 577: 1, 638: 1, 698: 1, 749: 1, 553: 1, 597: 1, 659: 1, 655: 1, 799: 1})
#
# The Value Counts in ERA Counter({3.73: 1, 4.07: 1, 3.67: 1, 3.98: 1, 4.64: 1, 3.8: 1, 4.03: 1, 4.05: 1, 3.74: 1, 4.31: 1, 4.24: 1, 3.57: 1, 3.94: 1, 4.16: 1, 4.14: 1, 2.94: 1, 3.21: 1, 3.36: 1, 4.28: 1, 4.33: 1, 3.43: 1, 3.62: 1, 4.02: 1, 4.41: 1, 4.69: 1, 3.44: 1, 3.72: 1, 4.04: 1, 4.09: 1, 5.04: 1})
#
# The Value Counts in CG Counter({1: 7, 2: 4, 7: 4, 3: 3, 0: 3, 5: 3, 6: 3, 4: 2, 11: 1})
#
# The Value Counts in SHO Counter({12: 7, 10: 5, 13: 3, 8: 2, 9: 2, 4: 2, 15: 2, 21: 2, 7: 2, 14: 1, 18: 1, 6: 1})
#
# The Value Counts in SV Counter({35: 4, 45: 3, 41: 3, 48: 2, 40: 2, 44: 2, 56: 1, 38: 1, 37: 1, 34: 1, 43: 1, 60: 1, 39: 1, 46: 1, 28: 1, 62: 1, 54: 1, 50: 1, 47: 1, 36: 1})
#
# The Value Counts in E Counter({88: 3, 86: 3, 90: 3, 93: 2, 77: 2, 95: 2, 79: 1, 101: 1, 97: 1, 119: 1, 85: 1, 94: 1, 126: 1, 96: 1, 122: 1, 111: 1, 116: 1, 117: 1, 75: 1, 78: 1, 92: 1})

# %%
#Checking the count-goemetry of the Target column only
print("The Value Counts in Wins - ",Counter(df['W']))
# Out:
# The Value Counts in Wins -  Counter({68: 3, 83: 2, 81: 2, 76: 2, 74: 2, 95: 1, 93: 1, 87: 1, 80: 1, 78: 1, 88: 1, 86: 1, 85: 1, 100: 1, 98: 1, 97: 1, 64: 1, 90: 1, 71: 1, 67: 1, 63: 1, 92: 1, 84: 1, 79: 1})

# %% [markdown]
# # Step 2.4 - Observations
#
#
# # The Dataset is made up of;
# - 30 rows and 17 columns
# - 16 features and 1 Target
#
# # Description of Features:
# - All the features have the following properties except ERA(Earned Running Average):
#   - It has no null values
#   - Its Datatypes are Interger type
#   - It is made up of Continous data
#   - It will not require encoding since they are made up of numerical data
#
# - ERA has the following properties:
#   - It has no null values
#   - Its Datatypes are floating type
#   - It is made up of Continous data
#   - It will not require encoding since they are made up of numerical data
#
# # About the Target/Label:
# W(Wins): This is the target variable and has the following properties:
# - It has no null values
# - Its Datatype is a interger type
# - It is made up of Continuos data
# - It will not require encoding since they are made up of numerical data
#
#
# **Since the target is made up of a continuos data hence this is a REGRESSION PROBLEM!

# %% [markdown]
# # Step 3 - EXPLORATORY DATA ANALYSIS(EDA) AND VISUALIZATION
# The objectives of the EDA is to ensure;
# 1. Independent Features will have a normal distribution using Data Transformation to remove skewness
# 2. Datasets will have the same scale using Normalization and Standardization
# 3. Column mean will be zero
# 4. Standard Deviation of the data should be 1

# %% [markdown]
# # Step 3.1 - Normal Distribution Check - Univariate Analysis

# %%
#Check for normal distribution and see how data is distributed for every column
plt.figure(figsize=(30,20), facecolor='red')#dimension and color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if plotnumber<=18:
        ax = plt.subplot(3,6,plotnumber)#3,6 means arrange the graphs in 3-rows and 6-columns spaces as seen below while plotnumber means plot graphs
        sns.distplot(df[column])#performing a distribution plot for all the columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 6
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Observations on Normal Distribution Check
# From the above density plot
# - We can see that some features does not obey a normal distribution, the building blocks is not in tandem with a normalized curve
#
# - The normal distribution of the sales columns also has no contribution to our Model Building since its the Target variable

# %% [markdown]
# # Step 3.2 - Scatter Plot Check(Bivariate Analysis)
# - Lets visualize the relationship between the features and the Label

# %%
#extracting only the features(wihtout the Label) from the original dataset and store in features
features=df.drop(columns=['W'],axis=1)
features
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# 12  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2   12
# 13  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6   12
# 14  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5   15
# 15  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1   15
# 16  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0   13
# 17  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6   21
# 18  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1    7
# 19  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2    8
# 20  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1   14
# 21  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4   13
# 22  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0   12
# 23  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3   10
# 24  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1    7
# 25  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6   21
# 26  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7   18
# 27  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1   12
# 28  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1    6
# 29  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4    4
#
#     SV    E
# 0   56   88
# 1   45   86
# 2   38   79
# 3   37  101
# 4   35   86
# 5   34   88
# 6   48   93
# 7   43   77
# 8   60   95
# 9   40   97
# 10  45  119
# 11  39   85
# 12  46   93
# 13  45   94
# 14  28  126
# 15  62   96
# 16  54  122
# 17  48  111
# 18  40  116
# 19  35   90
# 20  50   88
# 21  41   90
# 22  35   77
# 23  44   90
# 24  35  117
# 25  47   75
# 26  41   78
# 27  44   86
# 28  41   92
# 29  36   95

# %%
#Check for the relatinship between each features and Target
plt.figure(figsize=(30,20), facecolor='blue')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in features:#triggering your for loop
    if plotnumber<=16:#since there are 3 features
        ax = plt.subplot(4,4,plotnumber)#4,4 means arrange the graphs in 3-rows and 3-columns spaces as seen below while plotnumber means plot graphs
        sns.scatterplot(x=features[column],y=df['W'])#performing a relationship plot between features and label
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 16
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Observations on Scatter Plot
#
# From the above scatter plot we can see a strong relationship between the features and the Label(W).

# %% [markdown]
# # Step 3.3 - Correlation Check(Collinearity and Multicollinearity)- Multivariate Analysis;
#  - Collinearity Between Feature and Label
#  - Multicolinearity between features
#
# Lets see/visualize the correlation between (Features vs Label) and (Features vs Features)

# %%
#checking for general correlation
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
#checking for correlation between each feature and Label
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
#Plotting a barh chart to visualize correlation through the stand-alone bars
plt.figure(figsize=(15,8))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='barh', color='b')
plt.show()

# %% [markdown]
# # Multicollinearity Check

# %%
#Plotting a heatmap to show correlation through the brightness of the map-squares
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True, linewidth=0,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Hmmmm....we can see that most features do share a 'direct relationship' between each other! as we can some map-squares are brightened! That is:
#
# - ERA vs RA
# - ER vs RA
# - ERA vs ER
#
# But lets conlcude with our findings first and then consult Variance Inflation Factor for a final decision!

# %%
#lets also consumate further our quest for Multicollinearity check by ploting a pair plot
plt.figure(figsize=(30,20))
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Yet again! the pair plot reveals a level of camaraderie between some features...

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# # Observations on Correlation(Collinearity & Multicollinearity)
# From the above correlation statistics;
#
# Collinearity:
#
# - ERA has a negative correlation of 82% with the target column which can be considered as Strong bond
#
# - RA has a negative correlation of 81% with the target column which can be considered as Strong bond
#
# - ER has a negative correlation of 81% with the target column which can be considered as Strong bond
#
# - 3B has a negative correlation of 25% with the target column which can be considered as fair bond
#
# - SB has a negative correlation of 16% with the target column which can be considered as fair bond
#
# - E has a negative correlation of 9% with the target column which can be considered as weak bond
#
# - AB has a negative correlation of 9% with the target column which can be considered as weak bond
#
# - H has a positive correlation of 4% with the target column which can be considered as weak bond
#
# - CG has a positive correlation of 9% with the target column which can be considered as weak bond
#
# - SO has a positive correlation of 11% with the target column which can be considered as fair bond
#
# - HR has a positive correlation of 31% with the target column which can be considered as Strong bond
#
# - 2B has a positive correlation of 43% with the target column which can be considered as Strong bond
#
# - R has a positive correlation of 43% with the target column which can be considered as Strong bond
#
# - SHO has a positive correlation of 47% with the target column which can be considered as Strong bond
#
# - BB has a positive correlation of 48% with the target column which can be considered as Strong bond
#
# - SV has a positive correlation of 67% with the target column which can be considered as Strong bond
#
#
#  - Feature with Maximum correlation = 'SV(Save)'
#  - Feature with Minimum correlation = 'H(Hits)'
#
# Multicollinearity:
# - From the heatmap we can see that the some pairs of features have noticeable correllation between them:
#     - ERA vs RA
#     - ER vs RA
#     - ERA vs ER
#
# But we will reconfrim this during further steps by finding the Variance Inflation Factor(VIF)
#
#
# NB: Multicollinnearity means two variables are explaining the same thing, meaning one of them is useless and therefore we have to drop one of them!

# %% [markdown]
# # Step 3.4 - Outlier Check(Univariate Analysis)

# %%
#Check for allien-datapoints in each features data which has been stored in the dataframe; 'features_continuos'
plt.figure(figsize=(30,20))#dimension only
graph = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in features:#triggering your for loop
    if graph<=16:#this was made 8 just to allow for 4 spaces
        plt.subplot(4,4,graph)#4,4 means arrange the graphs in 4-rows and 4-columns spaces as seen below while plotnumber means plot graphs
        ax=sns.boxplot(data=features[column])#performing a box plot for all columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    graph+=1#incrementals for plot number so as to allow ploting one by one until it gets to 16
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Observations on Outlier Check
# From the above visualization plot its evident some feature posses outliers;
# - ERA
# - SHO
# - SV
# - E
#
# However this is subject to further analysis and reconfirmation using the zscore!

# %% [markdown]
# # Step 3.5 - Skewness Check(Univariate Analysis)

# %%
#Visualizing for skewness...
plt.figure(figsize=(30,20), facecolor='green')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in features:#triggering your for loop
    if plotnumber<=16:#since there are 4 features
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(features[column])#performing a distribution plot for all the columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 16
plt.tight_layout()#This is just to show you data in a compact form.

# %%
#Checking for skewness in each independent variable data which has been stored in the dataframe; 'features'
features.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Observations on Skewness Check:
# Lets assume Skewness threshold is taken as +/-0.50.Meaning any value outside +/-0.50 contains skewness. Hence the below features possess skewness:
#
# - R : 1.200786
# - H : 0.670254
# - HR : 0.516441
# - CG : 0.736845
# - SHO : 0.565790
# - SV : 0.657524
# - E : 0.890132
#
# ***We shall take care of these skewness using Power Transformation!

# %%
ax=sns.countplot(x='W',data=df)
print(df['W'].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# - from the above graph the dependent variable has many classes of wins of with the majority being 68!
# - We cant see any trace of imbalancing, hence we won't be needing SMOTE!

# %% [markdown]
# # Step 4 - DATA PREPROCESSING

# %% [markdown]
# # Step 4.1 - Removal of Duplicates and Unwanted Column

# %%
#Recheking shape of original data
df.shape
# Out:
# (30, 17)

# %%
#Remove duplicates
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (30, 17)

# %% [markdown]
# It appears there are no duplicates since there is no change in the number of rows!

# %% [markdown]
# # Step 4.2 - Feature Selection(Dropping of Features that has no correlation with target variable and once that strongly promotes multicollinearity(VIF))

# %%
#Now rechecking for correlation....
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
#Now lets compare correlation with target variable
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
#Lets have a view of the heatmap again with particular focus on map-squares that are more brightened
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True, linewidth=0,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Once again, from the heatmap above we can see that there is visible correlation between some features
#
#  - ERA vs RA
#  - ER vs RA
#  - ERA vs ER
#
# However, lets reconfirm by calculating the Variance Inflation Factor(VIF)!

# %% [markdown]
# # Variance Inflation Factor(VIF)
#
# To solve this multicollinearity problem, we have to first scale our data using Standard Scaler

# %%
X=df.drop(columns=['W'])
Y=df['W']

# %%
scalar=StandardScaler()
X_Scaled = scalar.fit_transform(X)
X_Scaled
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
#        [ 0.01327008,  1.28073815,  1.98408098,  0.80189192,  1.72234737,
#         -0.40377019, -0.25136033,  0.10586628, -0.02228984,  1.61880269,
#          1.59750126,  1.53131824,  1.3004422 ,  0.1728    , -1.04259994,
#         -0.60719689],
#        [ 3.50964704, -0.10488389,  1.36108904,  1.86983209, -1.39150098,
#          2.18504658,  1.79874163, -0.95279649,  0.20060853, -0.25718416,
#         -0.38910394, -0.35016492,  1.3004422 , -0.32091429, -1.17184786,
#         -0.46146963],
#        [ 1.31142984,  0.73226276, -0.11629183, -0.1536335 , -1.19688546,
#          1.54583256,  1.51351006, -0.20781158, -0.91388329,  0.13776044,
#          0.23442908,  0.16500309, -0.17175652, -1.80205719,  0.6376231 ,
#         -0.0971515 ],
#        [ 0.4286812 , -0.4512894 , -0.5968856 , -1.61502532, -1.0995777 ,
vif['vif']=[variance_inflation_factor(X_Scaled, i) for i in range(X_Scaled.shape[1])]#This is a list comprehension. in the for loop, the range(X_Scaled.shape[1]) which also means range(16) or (0,1,2,3,4,5....15), since X_Scaled.shape[1] means the first index in the X_Scaled.shape which is 16. Now all the columns in X_Scaled which is (0,1,2,3,4,5,6.....15) will now be compared with the entire X_Scaled one by one using the other part of the syntax which is variance_inflation_factor(X_Scaled, i). To shed more light, what happens here is that during th comparison using variance_inflation_factor(X_Scaled, i), the i is seen as a ‘Label’ while the X_Scaled is seen as a Feature. The output of this list comprehension is then stored in a column named 'vif' inside the empty ‘vif dataframe’ created above

# %%
vif['Features'] = X.columns#creating another column named 'Features' inside the empty vif Dataframe created earlier and populating it with a data called X.columns(i.e column names from the X DataFrame which was created by dropping the Label – ‘sales’ )
vif
# Out:
#             vif Features
# 0     11.522370        R
# 1     13.311532       AB
# 2     10.070668        H
# 3      4.019297       2B
# 4      3.294146       3B
# 5     10.079902       HR
# 6      3.806098       BB
# 7      2.652401       SO
# 8      2.102684       SB
# 9    191.839155       RA
# 10  1680.387145       ER
# 11  1222.722240      ERA
# 12     3.059904       CG
# 13     3.654331      SHO
# 14     5.798850       SV
# 15     2.186219        E

# %% [markdown]
# From the above vif dataframe,we are setting a vif threshold of 12, meaning any feature with Variance Inflation Factor greater than 12 is assumed to have a multicollinearity problem. it is not standard. The dataset demands.
#
# Hence, In lieu of the above assumption, we shall drop the following features:
#
# - ERA
# - RA
# - ER

# %%
#Dropping the values above
df.drop(columns=['ERA','RA','ER'],axis=1,inplace=True)
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 5    93  891  5509  1480  308  17  232  570  1151   88   7   10  34   88
# 6    87  764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101   5    9  45  119
# 11   86  729  5459  1363  278  26  230  486  1392  121   5   13  39   85
# 12   85  661  5417  1331  243  21  176  435  1150   52   2   12  46   93
# 13   76  656  5544  1379  262  22  198  478  1336   69   6   12  45   94
# 14   68  694  5600  1405  277  46  146  475  1119   78   5   15  28  126
# 15  100  647  5484  1386  288  39  137  506  1267   69   1   15  62   96
# 16   98  697  5631  1462  292  27  140  461  1322   98   0   13  54  122
# 17   97  689  5491  1341  272  30  171  567  1518   95   6   21  48  111
# 18   68  655  5480  1378  274  34  145  412  1299   84   1    7  40  116
# 19   64  640  5571  1382  257  27  167  496  1255  134   2    8  35   90
# 20   90  683  5527  1351  295  17  177  488  1290   51   1   14  50   88
# 21   83  703  5428  1363  265  13  177  539  1344   57   4   13  41   90
# 22   71  613  5463  1420  236  40  120  375  1150  112   0   12  35   77
# 23   67  573  5420  1361  251  18  100  471  1107   69   3   10  44   90
# 24   63  626  5529  1374  272  37  130  387  1274   88   1    7  35  117
# 25   92  667  5385  1346  263  26  187  563  1258   59   6   21  47   75
# 26   84  696  5565  1486  288  39  136  457  1159   93   7   18  41   78
# 27   79  720  5649  1494  289  48  154  490  1312  132   1   12  44   86
# 28   74  650  5457  1324  260  36  148  426  1327   82   1    6  41   92
# 29   68  737  5572  1479  274  49  186  388  1283   97   4    4  36   95

# %% [markdown]
# # Step 4.3 - Removal of Outliers
#
# This will be achieved using the zscore

# %%
#checking for allien-datapoints in each features data which has been stored in the dataframe; 'features_continuos'
plt.figure(figsize=(30,20))#dimension only
graph = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if graph<=15:#this was made 10 just to allow for 4 spaces
        plt.subplot(3,5,graph)#3,5 means arrange the graphs in 2-rows and 2-columns spaces as seen below while plotnumber means plot graphs
        ax=sns.boxplot(data=df[column])#performing a box plot for all columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    graph+=1#incrementals for plot number so as to allow ploting one by one until it gets to 10
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# Once again its visible we only have outlier issues in the SHO, SV and E columns! Now lets go ahead and remove them using zscore!

# %%
#Get the absolute value of the zscore of the remaining dataset
np.abs(zscore(df))
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# 12  0.392433  0.471376  1.432772  1.291077  1.783647  1.002270  0.395247
# 13  0.483244  0.557920  0.400291  0.436688  0.715707  0.904962  1.098383
# 14  1.261625  0.099814  1.208570  0.026106  0.127403  1.430424  0.563574
# 15  1.851896  0.713699  0.465723  0.312089  0.745685  0.749270  0.851220
# 16  1.657301  0.151740  1.656011  1.040693  0.970514  0.418423  0.755338
# 17  1.560004  0.013270  0.364688  1.113079  0.153633  0.126500  0.235444
# 18  1.261625  0.575229  0.523457  0.454487  0.041219  0.262731  0.595534
# 19  1.650815  0.834861  0.789997  0.383288  0.996744  0.418423  0.107601
# 20  0.878921  0.090583  0.154920  0.935081  1.139136  1.391501  0.427208
# 21  0.197838  0.255593  1.274002  0.721484  0.547085  1.780732  0.427208
# 22  0.969732  1.302198  0.768828  0.293103  2.177099  0.846578  1.394552
# 23  1.358922  1.994550  1.389471  0.757084  1.333988  1.294193  2.033766
# 24  1.748112  1.077184  0.183787  0.525687  0.153633  0.554654  1.074945
# 25  1.073516  0.367523  1.894646  1.024080  0.659500  0.515731  0.746815
# 26  0.295136  0.134432  0.703396  1.467888  0.745685  0.749270  0.883181
# 27  0.191352  0.549843  1.915815  1.610286  0.801892  1.625040  0.307888
# 28  0.677839  0.661773  0.855429  1.415675  0.828122  0.457346  0.499652
# 29  1.261625  0.844092  0.804431  1.343289  0.041219  1.722347  0.714854
#
#           BB        SO        SB        CG       SHO        SV         E
# 0   1.534902  2.697630  0.913883  0.539806  0.814629  1.671607  0.461470
# 1   0.536592  0.154878  0.601826  0.539806  0.172800  0.249879  0.607197
# 2   1.139144  0.893982  0.111449  2.772641  0.320914  0.654856  1.117242
# 3   1.160536  0.168602  0.690985  1.300442  0.567771  0.784104  0.485758
# 4   0.251360  0.105866  0.022290  1.300442  0.172800  1.042600  0.607197
# 5   1.798742  0.952796  0.200609  1.300442  0.320914  1.171848  0.461470
# 6   1.513510  0.207812  0.913883  0.171757  1.802057  0.637623  0.097152
# 7   0.910958  0.811641  1.760897  1.275906  0.320914  0.008617  1.262970
# 8   0.590073  0.605790  0.156029  0.907856  0.172800  2.188598  0.048576
# 9   0.158660  0.982204  0.557246  0.171757  0.320914  0.396360  0.194303
# 10  0.604334  0.148997  0.780144  0.564343  0.567771  0.249879  1.797303
# 11  0.301276  1.409590  1.671738  0.564343  0.419657  0.525608  0.680061
# 12  0.607900  0.962599  1.404260  0.539806  0.172800  0.379127  0.097152
# 13  0.158660  0.860654  0.646405  0.932393  0.172800  0.249879  0.024288
# 14  0.105179  1.266474  0.245188  0.564343  0.913371  1.947335  2.307348
# 15  0.657815  0.184286  0.646405  0.907856  0.913371  2.447094  0.121439
# 16  0.144398  0.723420  0.646405  1.275906  0.419657  1.413111  2.015894
# 17  1.745261  2.644696  0.512666  0.932393  2.394514  0.637623  1.214394
# 18  1.017920  0.497964  0.022290  0.907856  1.061486  0.396360  1.578712
# 19  0.479546  0.066657  2.251273  0.539806  0.814629  1.042600  0.315742
# 20  0.336930  0.409742  1.448839  0.907856  0.666514  0.896119  0.461470
# 21  1.246105  0.939073  1.181361  0.196293  0.419657  0.267112  0.315742
# 22  1.677518  0.962599  1.270521  1.275906  0.172800  1.042600  1.262970
# 23  0.033871  1.384104  0.646405  0.171757  0.320914  0.120631  0.315742
# 24  1.463595  0.252903  0.200609  0.907856  1.061486  1.042600  1.651576
# 25  1.673953  0.096064  1.092202  0.932393  2.394514  0.508375  1.408697
# 26  0.215706  0.874377  0.423507  1.300442  1.653943  0.267112  1.190106
# 27  0.372584  0.625395  2.162114  0.907856  0.172800  0.120631  0.607197
# 28  0.768343  0.772432  0.066870  0.907856  1.308343  0.267112  0.170015
# 29  1.445768  0.341125  0.601826  0.196293  1.802057  0.913352  0.048576

# %%
#checking the data shape
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 14)

# %% [markdown]
# Now we are setting threshold of outlier zscore>3, meaning any zscore above 3 is assumed to be an Outlier. Again, its not standard. The dataset demands.

# %%
#index number
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#Extracting out the non-outliers(i.e zscore<3) and storing output in new object
df_new=df[(z<3).all(axis=1)]
print("Old DataFrame",df.shape)#Data still with outliers
print("New DataFrame",df_new.shape)#Data without outliers
print("total_dropped_rows",df.shape[0]-df_new.shape[0])#Take note of this arithmetic in df.shape
# Out:
# Old DataFrame (30, 14)
# New DataFrame (29, 14)
# total_dropped_rows 1

# %% [markdown]
# Hmmm...this means there is only one real outliers! Lets move on! Data is looking great!

# %%
#Checking the new dataframe with non-outliers
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 6    87  764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87   1   12  60   95
 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if graph<=15:#this was made 10 just to allow for 4 spaces
        plt.subplot(3,5,graph)#3,5 means arrange the graphs in 2-rows and 2-columns spaces as seen below while plotnumber means plot graphs
        ax=sns.boxplot(data=df[column])#performing a box plot for all columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    graph+=1#incrementals for plot number so as to allow ploting one by one until it gets to 10
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# From the above we can see that the real outliers have been removed across the features!

# %% [markdown]
# # Step 4.4 - Transforming Data to Remove Skewness using Power transformation

# %%
#rechecking for skewness...
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
#Visualizing for the current skewness before Power Transformation
plt.figure(figsize=(30,20), facecolor='yellow')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df_new:#triggering your for loop
    if plotnumber<=10:#since there are 6 features
        ax = plt.subplot(2,5,plotnumber)#2,5 means arrange the graphs in 2-rows and 5-columns spaces as seen below while plotnumber means plot graphs
        sns.distplot(df_new[column])#performing a distribution plot for all the columns starting with volatile acidity
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 10
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# - Since we don't apply skewness removal on target data, we need to create a sub data frame that does not include the Wins         column
#
#
# - Using a skewness threshold of +/-0.5, from the skewness data, below features do have slewness:
#
#     - CG : 0.736845
#     - SHO : 0.565790
#     - SV : 0.657524
#     - E : 0.890132
#
# So lets go head and remove them using Power Transformation!

# %% [markdown]
# Before we apply Power Transformation lets remove all non-zero values from the features which were initially of interger datatypes(excluding the encoded independent variables)

# %%
#recall all their data types
df_new.dtypes
# Out:
# W      int64
# R      int64
# AB     int64
# H      int64
# 2B     int64
# 3B     int64
# HR     int64
# BB     int64
# SO     int64
# SB     int64
# CG     int64
# SHO    int64
# SV     int64
# E      int64
# dtype: object

# %% [markdown]
# Here we shall use 'mode' since all data are of interger type! We dont wan to risk having a floating data type by using mean!

# %%
df_new.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'CG', 'SHO',
#        'SV', 'E'],
#       dtype='object')

# %%
Power_data=df_new.drop(columns=['W'])

# %%
for i in Power_data.columns:
    df_new[i]=df_new[i].replace(0,df_new[i].mode()[0])
Power_data
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0   724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1   696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2   669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3   622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4   689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 5   764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 6   713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 7   644  5485  1383  278  32  167  436  1310   87   1   12  60   95
# 8   748  5640  1495  294  33  161  478  1148   71   3   10  40   97
# 9   751  5511  1419  279  32  172  503  1233  101   5    9  45  119
# 10  729  5459  1363  278  26  230  486  1392  121   5   13  39   85
# 11  661  5417  1331  243  21  176  435  1150   52   2   12  46   93
# 12  656  5544  1379  262  22  198  478  1336   69   6   12  45   94
# 13  694  5600  1405  277  46  146  475  1119   78   5   15  28  126
# 14  647  5484  1386  288  39  137  506  1267   69   1   15  62   96
# 15  697  5631  1462  292  27  140  461  1322   98   0   13  54  122
# 16  689  5491  1341  272  30  171  567  1518   95   6   21  48  111
# 17  655  5480  1378  274  34  145  412  1299   84   1    7  40  116
# 18  640  5571  1382  257  27  167  496  1255  134   2    8  35   90
# 19  683  5527  1351  295  17  177  488  1290   51   1   14  50   88
# 20  703  5428  1363  265  13  177  539  1344   57   4   13  41   90
# 21  613  5463  1420  236  40  120  375  1150  112   0   12  35   77
# 22  573  5420  1361  251  18  100  471  1107   69   3   10  44   90
# 23  626  5529  1374  272  37  130  387  1274   88   1    7  35  117
# 24  667  5385  1346  263  26  187  563  1258   59   6   21  47   75
# 25  696  5565  1486  288  39  136  457  1159   93   7   18  41   78
# 26  720  5649  1494  289  48  154  490  1312  132   1   12  44   86
# 27  650  5457  1324  260  36  148  426  1327   82   1    6  41   92
# 28  737  5572  1479  274  49  186  388  1283   97   4    4  36   95

# %% [markdown]
# Data is looking good, now lets go ahead with Power Transformation!

# %%
#Instantiating PowerTransformer,using 'yeo-johnson',into object 'scaler'
scaler = PowerTransformer(method ='yeo-johnson')#intstantiating using the yeo-johnson
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
#Now removing skewness by Power Transformation and updating dataset(df_new) with result
df_new[Power_data.columns] = scaler.fit_transform(df_new[Power_data.columns].values)

# %%
#revisualizing for the current skewness(if any) after Power Transformation
plt.figure(figsize=(30,20), facecolor='yellow')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df_new:#triggering your for loop
    if plotnumber<=10:#since there are 27 features
        ax = plt.subplot(2,5,plotnumber)#2,5 means arrange the graphs in 2-rows and 5-columns spaces as seen below while plotnumber means plot graphs
        sns.distplot(df_new[column])#performing a distribution plot for all the columns starting with volatile acidity
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 10
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# From the above we can see that skewness has been removed from columns that were initially of continuos data type!

# %%
#rechecking for skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.024842
# AB     0.081092
# H      0.000000
# 2B    -0.052793
# 3B    -0.075139
# HR     0.000448
# BB    -0.008572
# SO     0.051530
# SB    -0.009570
# CG     0.082483
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# From the above you can see all skewness is now within the threshold of +/-0.5 which was chosen earlier!

# %% [markdown]
# From the above we can see that skewness has been removed!
#
# NOTE:
#
#
# - The W column was not considered for skewness since its the Target data

# %% [markdown]
# # Step 4.5 - Seperating the datasets into X and Y variables

# %%
#seperation
X=df_new.drop(columns=['W'])
Y=df_new['W']

# %% [markdown]
# # Transforming data into standard normal distribution

# %%
#transforming dataset into a standard normal distribution
scalar=StandardScaler()
X_Scaled = scalar.fit_transform(X)
X_Scaled
# Out:
# array([[ 9.62543504e-01,  8.39431267e-01,  1.65963137e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -3.51720758e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01, -6.91704164e-01, -9.59650790e-01,
#          1.42758514e-01, -1.39412379e+00, -5.67101779e-01,
#          1.76148891e-01, -2.52844176e-01,  1.83903886e-01,
#         -1.67684998e-01],
#        [-1.22682499e+00,  2.02231472e-01, -4.13967008e-01,
#         -1.63010220e-01,  5.46877831e-01, -1.10289298e+00,
#         -1.51954034e+00,  1.93183556e-01,  3.09685564e-01,
#         -1.17328716e+00, -1.07533963e+00, -1.14916472e+00,
#          1.47295923e+00],
#        [-3.56234524e-01, -1.94135813e+00, -1.06878755e+00,
#         -6.75253462e-01, -5.35589865e-01,  9.08214214e-01,
#          1.72536184e+00,  3.42521724e-02, -1.10992538e+00,
#          1.08676533e+00,  2.09085582e+00,  5.58508906e-01,
#         -1.87019087e+00],
#        [ 2.98863300e-01,  7.03330340e-01,  1.44135785e+00,
#          8.44221534e-01,  7.32678154e-01, -8.60039342e-01,
#         -1.17954659e-01, -9.16970789e-01,  5.14700397e-01,
#          1.28339033e+00,  1.52182832e+00, -2.21933710e-01,
#         -1.45479212e+00],
#        [ 8.65848732e-01,  1.82306979e+00,  1.65963137e+00,
#          9.11434794e-01,  1.53626470e+00, -1.81252234e-01,
#          4.87456542e-01,  5.76375836e-01,  1.86548585e+00,
#         -1.17328716e+00,  2.36736538e-01,  1.83903886e-01,
#         -5.40819806e-01],
#        [-7.25080407e-01, -8.40177902e-01, -1.61447133e+00,
#         -8.37664770e-01,  4.52860860e-01, -3.99842255e-01,
#         -7.17272959e-01,  7.29844768e-01,  5.08613716e-02,
#         -1.17328716e+00, -1.38141238e+00, -2.21933710e-01,
#          1.90485434e-03],
#        [ 1.28115156e+00,  7.99219630e-01,  1.33222110e+00,
#         -4.39755655e-02,  1.62263592e+00,  8.77641898e-01,
#         -1.49822954e+00,  2.83212126e-01,  6.72393731e-01,
#          5.56770377e-01, -2.06403920e+00, -9.82263658e-01,
#          2.37592499e-01]])

# %% [markdown]
# What standard scaler does is to bring mean to zero and standard deviation to 1

# %%
#reconfirming that mean is 0
X_Scaled.mean()
# Out:
# -1.7669331956899043e-18

# %%
#reconfirming that standard deviation is 1
X_Scaled.std()
# Out:
# 1.0

# %% [markdown]
# # Step 5 - MODEL BUILDING

# %% [markdown]
# # Step 5.1 - Linear Regression

# %% [markdown]
# # Best Random State

# %%
#Using LinearRegression to get the best Random state
lm=LinearRegression()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    lm.fit(x_train,y_train)
    pred_train=lm.predict(x_train)
    pred_test=lm.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are: ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are: ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are: ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are: ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:  80.04 and 85.59 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:  2.9 and 3.22 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:  14.68 and 3.22 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:  3.83 and 1.79 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:  56.2 and 89.14 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:  7.0 and 2.55 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:  61.18 and 2.55 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:  7.82 and 1.6 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:  -53.14 and 87.39 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:  5.9 and 2.8 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:  58.92 and 2.8 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:  7.68 and 1.67 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:  77.09 and 85.23 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:  5.29 and 2.64 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:  39.3 and 2.64 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:  6.27 and 1.62 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:  37.68 and 89.2 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:  5.75 and 2.6 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:  55.13 and 2.6 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:  7.43 and 1.61 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:  -6.49 and 89.38 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:  8.07 and 2.83 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:  76.47 and 2.83 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:  8.74 and 1.68 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:  70.22 and 86.48 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:  5.3 and 2.95 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:  44.21 and 2.95 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:
respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:  -123.78 and 90.39 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:  8.03 and 2.44 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:  129.54 and 2.44 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:  11.38 and 1.56 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:  58.28 and 87.5 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:  3.55 and 2.9 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:  27.76 and 2.9 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:  5.27 and 1.7 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:  -147.34 and 91.49 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:  7.64 and 2.4 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:  107.73 and 2.4 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:  10.38 and 1.55 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:  65.83 and 86.99 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:  3.24 and 3.0 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:  23.51 and 3.0 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:  4.85 and 1.73 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:  62.59 and 84.69 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:  6.87 and 2.91 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:  80.62 and 2.91 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:  8.98 and 1.71 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:  2.38 and 89.72 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:  8.45 and 2.59 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:  115.41 and 2.59 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:  10.74 and 1.61 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:  42.97 and 86.39 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:  6.03 and 3.09 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:  46.89 and 3.09 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:  6.85 and 1.76 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:  31.96 and 87.45 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:  6.39 and 2.84 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:  64.05 and 2.84 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:  8.0 and 1.68 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:  22.54 and 85.72 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:  3.17 and 3.09 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:  12.5 and 3.09 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:  3.54 and 1.76 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:  72.86 and 87.63 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:  5.93 and 2.76 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:  44.48 and 2.76 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:  6.67 and 1.66 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:  58.72 and 92.78 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:  7.3 and 1.96 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:  81.82 and 1.96 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:  9.05 and 1.4 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:  71.16 and 85.58 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:  4.43 and 3.0 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:  31.98 and 3.0 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:  5.66 and 1.73 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:  19.35 and 84.6 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:  6.01 and 2.95 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:  56.72 and 2.95 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:  7.53 and 1.72 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:  65.44 and 87.84 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:  5.73 and 2.79 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:  49.04 and 2.79 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:  7.0 and 1.67 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:  -8.81 and 92.44 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:  7.43 and 2.33 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:  87.69 and 2.33 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:  9.36 and 1.53 respectively

# %% [markdown]
# The best accuracy is 92.66% at random state 28

# %% [markdown]
# We have found best_random state value as 28. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=28,test_size=0.20)

# %%
x_train.shape
# Out:
# (23, 13)

# %%
x_test.shape
# Out:
# (6, 13)

# %%
y_train.shape
# Out:
# (23,)

# %%
y_test.shape
# Out:
# (6,)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
lm=LinearRegression()#Initializing...
lm.fit(x_train,y_train)#Training...
pred_test=lm.predict(x_test)#Prediciting using test data...
pred_train=lm.predict(x_train)#Prediciting using training data...
Test_Accuracy_lm= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_lm= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_lm= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_lm= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_lm= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_lm= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_lm= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_lm= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_lm)#printing mean absolute error
print("Test_MSE ", Test_mse_lm)#printing mean squared error
print("Test_RMSE ", Test_rmse_lm)#printing root mean squared error
# Out:
# Test_Accuracy  92.66
# Test_MAE  2.2820486892998395
# Test_MSE  5.622771454278401
# Test_RMSE  2.3712383798931733

# %% [markdown]
# LinearRegression is producing average accuracy 92.66% which is very Good!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(lm,X,Y,cv=5)
CV_Score_lm=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_lm)
# Out:
# [-0.7356293  -1.62805868  0.4709916   0.28418042  0.59122463]
# Cross Validation Score is  -0.20345826890479884

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_lm
# Out:
# 0.9265530579266972

# %%
CV_Score_lm
# Out:
# -0.20345826890479884

# %%
lm_Acc_vs_CV_Score=np.abs(Test_Accuracy_lm-CV_Score_lm)
print("Difference between Accuracy and Cross Validation Score = ",lm_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.130011326831496

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is negligible (1.13) meaning that model is not having any overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.2 - Decision Tree Regressor

# %% [markdown]
# # Best Random State

# %%
#Using Decision Tree Regressor to get the best Random state
dt=DecisionTreeRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    dt.fit(x_train,y_train)
    pred_train=dt.predict(x_train)
    pred_test=dt.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are: ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are: ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are: ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are: ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:  28.4 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:  7.0 and 0.0 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:  52.67 and 0.0 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:
and 100.0 respectively
# At random state of :-  111 the mean absolute error of Testing and Training are:  7.5 and 0.0 respectively
# At random state of :-  111 the mean squared error of Testing and Training are:  94.83 and 0.0 respectively
# At random state of :-  111 the root mean squared error of Testing and Training are:  9.74 and 0.0 respectively
#
#
# At random state of :- 112 Testing Accuracy and Training Accuracy are:  -120.23 and 100.0 respectively
# At random state of :-  112 the mean absolute error of Testing and Training are:  8.67 and 0.0 respectively
# At random state of :-  112 the mean squared error of Testing and Training are:  107.67 and 0.0 respectively
# At random state of :-  112 the root mean squared error of Testing and Training are:  10.38 and 0.0 respectively
#
#
# ...
# At random state of :-  162 the root mean squared error of Testing and Training are:  13.44 and 0.0 respectively
#
#
# At random state of :- 163 Testing Accuracy and Training Accuracy are:  59.84 and 100.0 respectively
# At random state of :-  163 the mean absolute error of Testing and Training are:  5.67 and 0.0 respectively
# At random state of :-  163 the mean squared error of Testing and Training are:  35.67 and 0.0 respectively
# At random state of :-  163 the root mean squared error of Testing and Training are:  5.97 and 0.0 respectively
#
#
# At random state of :- 164 Testing Accuracy and Training Accuracy are:  57.45 and 100.0 respectively
# At random state of :-  164 the mean absolute error of Testing and Training are:  5.17 and 0.0 respectively
# At random state of :-  164 the mean squared error of Testing and Training are:  35.83 and 0.0 respectively
# At random state of :-  164 the root mean squared error of Testing and Training are:  5.99 and 0.0 respectively
#
#
# At random state of :- 165 Testing Accuracy and Training Accuracy are:  36.7 and 100.0 respectively
# At random state of :-  165 the mean absolute error of Testing and Training are:  7.17 and 0.0 respectively
# At random state of :-  165 the mean squared error of Testing and Training are:  74.83 and 0.0 respectively
# At random state of :-  165 the root mean squared error of Testing and Training are:  8.65 and 0.0 respectively
#
#
# At random state of :- 166 Testing Accuracy and Training Accuracy are:  -59.29 and 100.0 respectively
# At random state of :-  166 the mean absolute error of Testing and Training are:  7.5 and 0.0 respectively
# At random state of :-  166 the mean squared error of Testing and Training are:  102.83 and 0.0 respectively
# At random state of :-  166 the root mean squared error of Testing and Training are:  10.14 and 0.0 respectively
#
#
# At random state of :- 167 Testing Accuracy and Training Accuracy are:  -129.58 and 100.0 respectively
# At random state of :-  167 the mean absolute error of Testing and Training are:  11.17 and 0.0 respectively
# At random state of :-  167 the mean squared error of Testing and Training are:  221.17 and 0.0 respectively
# At random state of :-  167 the root mean squared error of Testing and Training are:  14.87 and 0.0 respectively
#
#
# At random state of :- 168 Testing Accuracy and Training Accuracy are:  40.49 and 100.0 respectively
# At random state of :-  168 the mean absolute error of Testing and Training are:  5.67 and 0.0 respectively
# At random state of :-  168 the mean squared error of Testing and Training are:  59.0 and 0.0 respectively
# At random state of :-  168 the root mean squared error of Testing and Training are:  7.68 and 0.0 respectively
#
#
# At random state of :- 169 Testing Accuracy and Training Accuracy are:  18.49 and 100.0 respectively
# At random state of :-  169 the mean absolute error of Testing and Training are:  8.17 and 0.0 respectively
# At random state of :-  169 the mean squared error of Testing and Training are:  89.5 and 0.0 respectively
# At random state of :-  169 the root mean squared error of Testing and Training are:  9.46 and 0.0 respectively
#
#
# At random state of :- 170 Testing Accuracy and Training Accuracy are:  -73.44 and 100.0 respectively
# At random state of :-  170 the mean absolute error of Testing and Training are:  8.33 and 0.0 respectively
# At random state of :-  170 the mean squared error of Testing and Training are:  94.67 and 0.0 respectively
# At random state of :-  170 the root mean squared error of Testing and Training are:  9.73 and 0.0 respectively
#
#
# At random state of :- 171 Testing Accuracy and Training Accuracy are:  19.55 and 100.0 respectively
# At random state of :-  171 the mean absolute error of Testing and Training are:  8.33 and 0.0 respectively
# At random state of :-  171 the mean squared error of Testing and Training are:  74.67 and 0.0 respectively
# At random state of :-  171 the root mean squared error of Testing and Training are:  8.64 and 0.0 respectively
#
#
# At random state of :- 172 Testing Accuracy and Training Accuracy are:  -107.98 and 100.0 respectively
# At random state of :-  172 the mean absolute error of Testing and Training are:  8.67 and 0.0 respectively
# At random state of :-  172 the mean squared error of Testing and Training are:  105.67 and 0.0 respectively
# At random state of :-  172 the root mean squared error of Testing and Training are:  10.28 and 0.0 respectively
#
#
# At random state of :- 173 Testing Accuracy and Training Accuracy are:  2.25 and 100.0 respectively
# At random state of :-  173 the mean absolute error of Testing and Training are:  11.5 and 0.0 respectively
# At random state of :-  173 the mean squared error of Testing and Training are:  190.5 and 0.0 respectively
# At random state of :-  173 the root mean squared error of Testing and Training are:  13.8 and 0.0 respectively
#
#
# At random state of :- 174 Testing Accuracy and Training Accuracy are:  19.2 and 100.0 respectively
# At random state of :-  174 the mean absolute error of Testing and Training are:  6.17 and 0.0 respectively
# At random state of :-  174 the mean squared error of Testing and Training are:  66.17 and 0.0 respectively
# At random state of :-  174 the root mean squared error of Testing and Training are:  8.13 and 0.0 respectively
#
#
# At random state of :- 175 Testing Accuracy and Training Accuracy are:  38.77 and 100.0 respectively
# At random state of :-  175 the mean absolute error of Testing and Training are:  7.67 and 0.0 respectively
# At random state of :-  175 the mean squared error of Testing and Training are:  73.0 and 0.0 respectively
# At random state of :-  175 the root mean squared error of Testing and Training are:  8.54 and 0.0 respectively
#
#
# At random state of :- 176 Testing Accuracy and Training Accuracy are:  8.38 and 100.0 respectively
# At random state of :-  176 the mean absolute error of Testing and Training are:  7.5 and 0.0 respectively
# At random state of :-  176 the mean squared error of Testing and Training are:  79.83 and 0.0 respectively
# At random state of :-  176 the root mean squared error of Testing and Training are:  8.93 and 0.0 respectively
#
#
# At random state of :- 177 Testing Accuracy and Training Accuracy are:  -58.19 and 100.0 respectively
# At random state of :-  177 the mean absolute error of Testing and Training are:  6.5 and 0.0 respectively
# At random state of :-  177 the mean squared error of Testing and Training are:  61.17 and 0.0 respectively
# At random state of :-  177 the root mean squared error of Testing and Training are:  7.82 and 0.0 respectively
#
#
# At random state of :- 178 Testing Accuracy and Training Accuracy are:  41.44 and 100.0 respectively
# At random state of :-  178 the mean absolute error of Testing and Training are:  6.83 and 0.0 respectively
# At random state of :-  178 the mean squared error of Testing and Training are:  60.83 and 0.0 respectively
# At random state of :-  178 the root mean squared error of Testing and Training are:  7.8 and 0.0 respectively
#
#
# At random state of :- 179 Testing Accuracy and Training Accuracy are:  11.39 and 100.0 respectively
# At random state of :-  179 the mean absolute error of Testing and Training are:  6.5 and 0.0 respectively
# At random state of :-  179 the mean squared error of Testing and Training are:  75.83 and 0.0 respectively
# At random state of :-  179 the root mean squared error of Testing and Training are:  8.71 and 0.0 respectively
#
#
# At random state of :- 180 Testing Accuracy and Training Accuracy are:  9.59 and 100.0 respectively
# At random state of :-  180 the mean absolute error of Testing and Training are:  7.33 and 0.0 respectively
# At random state of :-  180 the mean squared error of Testing and Training are:  58.67 and 0.0 respectively
# At random state of :-  180 the root mean squared error of Testing and Training are:  7.66 and 0.0 respectively
#
#
# At random state of :- 181 Testing Accuracy and Training Accuracy are:  -30.63 and 100.0 respectively
# At random state of :-  181 the mean absolute error of Testing and Training are:  8.33 and 0.0 respectively
# At random state of :-  181 the mean squared error of Testing and Training are:  100.33 and 0.0 respectively
# At random state of :-  181 the root mean squared error of Testing and Training are:  10.02 and 0.0 respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:  28.59 and 100.0 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:  8.33 and 0.0 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:  83.0 and 0.0 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:  9.11 and 0.0 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:  55.61 and 100.0 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:  5.33 and 0.0 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:  32.67 and 0.0 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:  5.72 and 0.0 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:  72.89 and 100.0 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:  4.67 and 0.0 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:  26.0 and 0.0 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:  5.1 and 0.0 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:  45.3 and 100.0 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:  5.0 and 0.0 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:  31.67 and 0.0 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:  5.63 and 0.0 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:  -145.41 and 100.0 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:  10.67 and 0.0 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:  163.33 and 0.0 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:  12.78 and 0.0 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:  -111.99 and 100.0 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:  8.67 and 0.0 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:  92.33 and 0.0 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:  9.61 and 0.0 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:  58.82 and 100.0 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:  4.33 and 0.0 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:  28.33 and 0.0 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:  5.32 and 0.0 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:  43.15 and 100.0 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:  9.5 and 0.0 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:  122.5 and 0.0 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:  11.07 and 0.0 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:  87.03 and 100.0 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:  3.33 and 0.0 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:  15.33 and 0.0 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:  3.92 and 0.0 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:  -29.53 and 100.0 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:  7.83 and 0.0 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:  106.5 and 0.0 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:  10.32 and 0.0 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:  -42.17 and 100.0 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:  10.83 and 0.0 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:  133.83 and 0.0 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:  11.57 and 0.0 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:  -133.39 and 100.0 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:  5.67 and 0.0 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:  37.67 and 0.0 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:  6.14 and 0.0 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:  50.69 and 100.0 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:  7.83 and 0.0 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:  80.83 and 0.0 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:  8.99 and 0.0 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:  37.78 and 100.0 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:  9.67 and 0.0 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:  123.33 and 0.0 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:  11.11 and 0.0 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:  66.78 and 100.0 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:  5.5 and 0.0 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:  36.83 and 0.0 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:  6.07 and 0.0 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:  -59.72 and 100.0 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:  9.67 and 0.0 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:  112.33 and 0.0 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:  10.6 and 0.0 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:  12.73 and 100.0 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:  8.83 and 0.0 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:  123.83 and 0.0 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:  11.13 and 0.0 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:  -4.45 and 100.0 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:  8.5 and 0.0 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:  84.17 and 0.0 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:  9.17 and 0.0 respectively

# %% [markdown]
# The best accuracy is 89.99% at random state 190

# %% [markdown]
# We have found best_random state value as 190. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=196,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
dt=DecisionTreeRegressor()#Initializing...
dt.fit(x_train,y_train)#Training...
pred_test=dt.predict(x_test)#Prediciting using test data...
pred_train=dt.predict(x_train)#Prediciting using training data...
Test_Accuracy_dt= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_dt= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_dt= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_dt= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_dt= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_dt= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_dt= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_dt= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_dt)#printing mean absolute error
print("Test_MSE ", Test_mse_dt)#printing mean squared error
print("Test_RMSE ", Test_rmse_dt)#printing root mean squared error
# Out:
# Test_Accuracy  82.26
# Test_MAE  3.6666666666666665
# Test_MSE  19.666666666666668
# Test_RMSE  4.43471156521669

# %% [markdown]
# Decision Tree is producing good accuracy 82.26% which is very Good!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(dt,X,Y,cv=5)
CV_Score_dt=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_dt)
# Out:
# [-0.90909091 -3.82894737  0.36595567  0.24918033  0.15978774]
# Cross Validation Score is  -0.7926229093418302

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_dt
# Out:
# 0.8226452905811623

# %%
CV_Score_dt
# Out:
# -0.7926229093418302

# %%
dt_Acc_vs_CV_Score=np.abs(Test_Accuracy_dt-CV_Score_dt)
print("Difference between Accuracy and Cross Validation Score = ",dt_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.6152681999229925

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is negligible (1.62) meaning that model is not having any overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.3 - RandomForest Regressor

# %% [markdown]
# # Best Random State

# %%
#Using RandomForest Regressor to get the best Random state
rf=RandomForestRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    rf.fit(x_train,y_train)
    pred_train=rf.predict(x_train)
    pred_test=rf.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are: ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are: ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are: ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are: ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:  46.45 and 92.2 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:  5.49 and 2.38 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:  39.39 and 2.38 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:  6.28 and 1.54 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:  53.92 and 92.57 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:  6.25 and 2.24 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:  64.35 and 2.24 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:  8.02 and 1.5 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:  -83.01 and 90.14 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:  6.95 and 2.41 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:  70.41 and 2.41 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:  8.39 and 1.55 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:  61.95 and 90.24 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:  7.63 and 2.06 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:  65.28 and 2.06 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:  8.08 and 1.44 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:  61.58 and 90.18 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:  4.69 and 2.58 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:  33.99 and 2.58 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:  5.83 and 1.61 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:  49.97 and 92.59 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:  5.28 and 2.4 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:  35.92 and 2.4 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:  5.99 and 1.55 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:  39.17 and 92.08 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:  7.79 and 2.28 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:  90.31 and 2.28 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:  9.5 and 1.51 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:  44.43 and 91.45 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:  4.24 and 2.49 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:  24.82 and 2.49 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:  4.98 and 1.58 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:  47.35 and 89.23 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:  7.69 and 2.41 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:  83.96 and 2.41 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:  9.16 and 1.55 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:  30.08 and 94.63 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:  6.27 and 1.82 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:  46.71 and 1.82 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:  6.83 and 1.35 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:  30.59 and 92.92 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:  4.74 and 2.41 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:  35.86 and 2.41 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:  5.99 and 1.55 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:  56.16 and 92.21 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:  4.06 and 2.51 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:  23.59 and 2.51 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:  4.86 and 1.58 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:  23.32 and 94.82 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:  5.27 and 2.01 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:  54.7 and 2.01 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:  7.4 and 1.42 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:  72.9 and 90.43 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:  3.67 and 2.55 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:  21.02 and 2.55 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:  4.58 and 1.6 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:  45.8 and 93.46 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:  4.54 and 2.35 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:  29.63 and 2.35 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:  5.44 and 1.53 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:  49.19 and 90.64 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:  7.1 and 2.32 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:  83.5 and 2.32 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:  9.14 and 1.52 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:  -16.08 and 94.97 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:  6.9 and 2.05 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:  69.04 and 2.05 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:  8.31 and 1.43 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:  58.22 and 87.6 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:  6.15 and 2.77 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:  52.04 and 2.77 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:  7.21 and 1.66 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:  -7.96 and 93.06 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:  7.15 and 2.32 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:  78.09 and 2.32 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:  8.84 and 1.52 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:  -1.38 and 92.39 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:  7.72 and 2.05 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:  67.47 and 2.05 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:  8.21 and 1.43 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:  -29.84 and 91.96 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:  7.04 and 2.3 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:  60.77 and 2.3 respectively
# At random state of :-  20 the root mean squared error of Testing and Training are:  7.8 and 1.52 respectively
#
#
# At random state of :- 21 Testing Accuracy and Training Accuracy are:  13.25 and 94.3 respectively
# At random state of :-  21 the mean absolute error of Testing and Training are:  5.9 and 2.23 respectively
# At random state of :-  21 the mean squared error of Testing and Training are:  58.32 and 2.23 respectively
# At random state of :-  21 the root mean squared error of Testing and Training are:  7.64 and 1.49 respectively
#
#
# At random state of :- 22 Testing Accuracy and Training Accuracy are:  2.67 and 91.86 respectively
# At random state of :-  22 the mean absolute error of Testing and Training are:  7.41 and 2.21 respectively
# At random state of :-  22 the mean squared error of Testing and Training are:  74.86 and 2.21 respectively
# At random state of :-  22 the root mean squared error of Testing and Training are:  8.65 and 1.49 respectively
#
#
# At random state of :- 23 Testing Accuracy and Training Accuracy are:  40.24 and 90.08 respectively
# At random state of :-  23 the mean absolute error of Testing and Training are:  5.38 and 2.5 respectively
# At random state of :-  23 the mean squared error of Testing and Training are:  40.44 and 2.5 respectively
# At random state of :-  23 the root mean squared error of Testing and Training are:  6.36 and 1.58 respectively
#
#
# At random state of :- 24 Testing Accuracy and Training Accuracy are:  -14.01 and 92.55 respectively
# At random state of :-  24 the mean absolute error of Testing and Training are:  3.67 and 2.68 respectively
# At random state of :-  24 the mean squared error of Testing and Training are:  22.33 and 2.68 respectively
# At random state of :-  24 the root mean squared error of Testing and Training are:
respectively
# At random state of :-  171 the mean squared error of Testing and Training are:  28.54 and 2.26 respectively
# At random state of :-  171 the root mean squared error of Testing and Training are:  5.34 and 1.5 respectively
#
#
# At random state of :- 172 Testing Accuracy and Training Accuracy are:  0.75 and 94.68 respectively
# At random state of :-  172 the mean absolute error of Testing and Training are:  5.74 and 2.05 respectively
# At random state of :-  172 the mean squared error of Testing and Training are:  50.42 and 2.05 respectively
# At random state of :-  172 the root mean squared error of Testing and Training are:  7.1 and 1.43 respectively
#
#
# At random state of :- 173 Testing Accuracy and Training Accuracy are:  45.05 and 89.85 respectively
# At random state of :-  173 the mean absolute error of Testing and Training are:  9.04 and 2.27 respectively
# At random state of :-  173 the mean squared error of Testing and Training are:  107.08 and 2.27 respectively
# At random state of :-  173 the root mean squared error of Testing and Training are:  10.35 and 1.51 respectively
#
#
# At random state of :- 174 Testing Accuracy and Training Accuracy are:  30.26 and 93.19 respectively
# At random state of :-  174 the mean absolute error of Testing and Training are:  5.79 and 2.2 respectively
# At random state of :-  174 the mean squared error of Testing and Training are:  57.11 and 2.2 respectively
# At random state of :-  174 the root mean squared error of Testing and Training are:  7.56 and 1.48 respectively
#
#
# At random state of :- 175 Testing Accuracy and Training Accuracy are:  31.89 and 93.24 respectively
# At random state of :-  175 the mean absolute error of Testing and Training are:  6.7 and 2.04 respectively
# At random state of :-  175 the mean squared error of Testing and Training are:  81.2 and 2.04 respectively
# At random state of :-  175 the root mean squared error of Testing and Training are:  9.01 and 1.43 respectively
#
#
# At random state of :- 176 Testing Accuracy and Training Accuracy are:  65.61 and 92.57 respectively
# At random state of :-  176 the mean absolute error of Testing and Training are:  4.59 and 2.35 respectively
# At random state of :-  176 the mean squared error of Testing and Training are:  29.97 and 2.35 respectively
# At random state of :-  176 the root mean squared error of Testing and Training are:  5.47 and 1.53 respectively
#
#
# At random state of :- 177 Testing Accuracy and Training Accuracy are:  -8.63 and 92.59 respectively
# At random state of :-  177 the mean absolute error of Testing and Training are:  5.73 and 2.42 respectively
# At random state of :-  177 the mean squared error of Testing and Training are:  42.0 and 2.42 respectively
# At random state of :-  177 the root mean squared error of Testing and Training are:  6.48 and 1.56 respectively
#
#
# At random state of :- 178 Testing Accuracy and Training Accuracy are:  42.73 and 90.53 respectively
# At random state of :-  178 the mean absolute error of Testing and Training are:  6.51 and 2.49 respectively
# At random state of :-  178 the mean squared error of Testing and Training are:  59.49 and 2.49 respectively
# At random state of :-  178 the root mean squared error of Testing and Training are:  7.71 and 1.58 respectively
#
#
# At random state of :- 179 Testing Accuracy and Training Accuracy are:  44.06 and 94.76 respectively
# At random state of :-  179 the mean absolute error of Testing and Training are:  5.59 and 2.04 respectively
# At random state of :-  179 the mean squared error of Testing and Training are:  47.87 and 2.04 respectively
# At random state of :-  179 the root mean squared error of Testing and Training are:  6.92 and 1.43 respectively
#
#
# At random state of :- 180 Testing Accuracy and Training Accuracy are:  41.54 and 92.87 respectively
# At random state of :-  180 the mean absolute error of Testing and Training are:  5.11 and 2.26 respectively
# At random state of :-  180 the mean squared error of Testing and Training are:  37.93 and 2.26 respectively
# At random state of :-  180 the root mean squared error of Testing and Training are:  6.16 and 1.5 respectively
#
#
# At random state of :- 181 Testing Accuracy and Training Accuracy are:  54.25 and 93.64 respectively
# At random state of :-  181 the mean absolute error of Testing and Training are:  5.11 and 2.23 respectively
# At random state of :-  181 the mean squared error of Testing and Training are:  35.14 and 2.23 respectively
# At random state of :-  181 the root mean squared error of Testing and Training are:  5.93 and 1.49 respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:  38.24 and 94.94 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:  7.69 and 1.82 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:  71.78 and 1.82 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:  8.47 and 1.35 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:  65.57 and 91.9 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:  4.32 and 2.42 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:  25.33 and 2.42 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:  5.03 and 1.56 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:  67.51 and 93.13 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:  4.82 and 2.08 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:  31.17 and 2.08 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:  5.58 and 1.44 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:  -47.78 and 91.5 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:  8.28 and 2.16 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:  85.55 and 2.16 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:  9.25 and 1.47 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:  24.46 and 91.99 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:  6.07 and 2.38 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:  50.27 and 2.38 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:  7.09 and 1.54 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:  -39.12 and 93.52 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:  6.78 and 2.08 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:  60.59 and 2.08 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:  7.78 and 1.44 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:  68.59 and 90.49 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:  3.54 and 2.62 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:  21.61 and 2.62 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:  4.65 and 1.62 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:  46.05 and 90.85 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:  9.96 and 2.05 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:  116.25 and 2.05 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:  10.78 and 1.43 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:  48.33 and 87.88 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:  5.62 and 2.76 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:  61.09 and 2.76 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:  7.82 and 1.66 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:  36.47 and 91.97 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:  6.38 and 2.42 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:  52.24 and 2.42 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:  7.23 and 1.55 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:  43.87 and 91.99 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:  6.61 and 2.21 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:  52.84 and 2.21 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:  7.27 and 1.49 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:  -219.61 and 91.71 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:  6.22 and 2.32 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:  51.58 and 2.32 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:  7.18 and 1.52 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:  57.47 and 94.2 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:  7.53 and 1.88 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:  69.72 and 1.88 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:  8.35 and 1.37 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:  52.73 and 91.34 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:  7.88 and 2.09 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:  93.7 and 2.09 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:  9.68 and 1.44 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:  63.06 and 92.17 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:  5.82 and 2.35 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:  40.97 and 2.35 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:  6.4 and 1.53 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:  -0.42 and 91.67 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:  6.49 and 2.25 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:  70.63 and 2.25 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:  8.4 and 1.5 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:  43.62 and 93.34 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:  7.25 and 2.08 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:  80.0 and 2.08 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:  8.94 and 1.44 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:  -9.08 and 92.06 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:  7.41 and 2.06 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:  87.9 and 2.06 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:  9.38 and 1.44 respectively

# %% [markdown]
# The best accuracy is 81.07% at random state 162

# %% [markdown]
# We have found best_random state value as 162. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
#using the random state of 162
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=162,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
rf=RandomForestRegressor()#Initializing...
rf.fit(x_train,y_train)#Training...
pred_test=rf.predict(x_test)#Prediciting using test data...
pred_train=rf.predict(x_train)#Prediciting using training data...
Test_Accuracy_rf= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_rf= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_rf= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_rf= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_rf= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_rf= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_rf= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_rf= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_rf)#printing mean absolute error
print("Test_MSE ", Test_mse_rf)#printing mean squared error
print("Test_RMSE ", Test_rmse_rf)#printing root mean squared error
# Out:
# Test_Accuracy  81.3
# Test_MAE  4.259999999999998
# Test_MSE  25.52023333333331
# Test_RMSE  5.0517554704610665

# %% [markdown]
# RandomForest is producing very good accuracy = 81.3%!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(rf,X,Y,cv=5)
CV_Score_rf=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_rf)
# Out:
# [ 0.19704352 -4.23018158  0.35598938  0.23326246  0.74029953]
# Cross Validation Score is  -0.5407173384144075

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_rf
# Out:
# 0.8130005292082232

# %%
CV_Score_rf
# Out:
# -0.5407173384144075

# %%
rf_Acc_vs_CV_Score=np.abs(Test_Accuracy_rf-CV_Score_rf)
print("Difference between Accuracy and Cross Validation Score = ",rf_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.3537178676226307

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is low (1.35) meaning that model is not having any overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.4 - AdaBoost Regressor

# %% [markdown]
# # Best Random State

# %%
#Using AdaBoost Regressor to get the best Random state
ada=AdaBoostRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    ada.fit(x_train,y_train)
    pred_train=ada.predict(x_train)
    pred_test=ada.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are: ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are: ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are: ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are: ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:  64.42 and 99.13 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:  4.68 and 0.71 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:  26.17 and 0.71 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:  5.12 and 0.84 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:  41.34 and 97.89 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:  7.24 and 0.93 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:  81.92 and 0.93 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:  9.05 and 0.96 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:  -189.59 and 97.36 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:  8.31 and 1.03 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:  111.41 and 1.03 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:  10.56 and 1.01 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:  50.87 and 98.1 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:  8.55 and 0.84 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:  84.28 and 0.84 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:  9.18 and 0.92 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:  81.37 and 98.48 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:  3.86 and 0.82 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:  16.48 and 0.82 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:  4.06 and 0.91 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:  55.72 and 99.35 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:  5.26 and 0.56 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:  31.79 and 0.56 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:  5.64 and 0.75 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:  32.63 and 98.51 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:  8.18 and 0.63 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:  100.02 and 0.63 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:  10.0 and 0.79 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:  11.66 and 98.53 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:  6.01 and 0.92 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:  39.46 and 0.92 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:  6.28 and 0.96 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:  63.52 and 97.66 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:  7.08 and 0.89 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:  58.17 and 0.89 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:  7.63 and 0.95 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:  -17.32 and 98.5 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:  7.43 and 0.72 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:  78.38 and 0.72 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:  8.85 and 0.85 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:  47.53 and 98.72 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:  4.33 and 0.67 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:  27.11 and 0.67 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:  5.21 and 0.82 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:  55.26 and 98.93 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:  4.15 and 0.58 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:  24.07 and 0.58 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:  4.91 and 0.76 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:  8.52 and 99.04 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:  6.11 and 0.58 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:  65.26 and 0.58 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:  8.08 and 0.76 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:  85.64 and 98.27 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:  2.85 and 0.82 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:  11.13 and 0.82 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:  3.34 and 0.91 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:  32.5 and 98.41 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:  5.38 and 0.86 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:  36.9 and 0.86 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:  6.07 and 0.93 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:  27.87 and 97.19 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:  9.6 and 0.99 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:  118.53 and 0.99 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:  10.89 and 0.99 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:  -17.43 and 98.43 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:  6.26 and 0.73 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:  69.84 and 0.73 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:  8.36 and 0.85 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:  49.94 and 97.82 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:  7.09 and 0.94 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:  62.35 and 0.94 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:  7.9 and 0.97 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:  -30.19 and 98.71 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:  8.38 and 0.75 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:  94.17 and 0.75 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:  9.7 and 0.87 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:  -8.4 and 98.98 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:  8.0 and 0.66 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:  72.15 and 0.66 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:  8.49 and 0.82 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:  -49.51 and 99.03 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:
respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:  9.62 and 0.8 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:  -4.79 and 98.9 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:  6.77 and 0.52 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:  84.44 and 0.52 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:  9.19 and 0.72 respectively

# %% [markdown]
# The best accuracy is 90% at random state 146

# %% [markdown]
# We have found best_random state value as 146. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=13,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
ada=AdaBoostRegressor()#Initializing...
ada.fit(x_train,y_train)#Training...
pred_test=ada.predict(x_test)#Prediciting using test data...
pred_train=ada.predict(x_train)#Prediciting using training data...
Test_Accuracy_ada= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_ada= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_ada= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_ada= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_ada= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_ada= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_ada= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_ada= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_ada)#printing mean absolute error
print("Test_MSE ", Test_mse_ada)#printing mean squared error
print("Test_RMSE ", Test_rmse_ada)#printing root mean squared error
# Out:
# Test_Accuracy  81.48
# Test_MAE  3.68452380952381
# Test_MSE  14.360378873771737
# Test_RMSE  3.789509054451742

# %% [markdown]
# AdaBoost is producing good accuracy = 81.48%!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(ada,X,Y,cv=5)
CV_Score_ada=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_ada)
# Out:
# [ 0.2897016  -4.88450292  0.17545662  0.22551361  0.70318687]
# Cross Validation Score is  -0.6981288434553359

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_ada
# Out:
# 0.8148375216848917

# %%
CV_Score_ada
# Out:
# -0.6981288434553359

# %%
ada_Acc_vs_CV_Score=np.abs(Test_Accuracy_ada-CV_Score_ada)
print("Difference between Accuracy and Cross Validation Score = ",ada_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.5129663651402274

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is low (1.512) meaning that model is not having any overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.5 - GradientBoosting Regressor

# %% [markdown]
# # Best Random State

# %%
#Using GradientBoosting to get the best Random state
gb=GradientBoostingRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    gb.fit(x_train,y_train)
    pred_train=gb.predict(x_train)
    pred_test=gb.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are: ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are: ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are: ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are: ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:  43.82 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:  5.36 and 0.01 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:  41.32 and 0.01 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:  6.43 and 0.1 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:  33.38 and 100.0 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:  6.98 and 0.01 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:  93.04 and 0.01 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:  9.65 and 0.08 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:  -63.86 and 100.0 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:  6.9 and 0.01 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:  63.04 and 0.01 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:  7.94 and 0.11 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:  74.52 and 100.0 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:  6.1 and 0.0 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:  43.71 and 0.0 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:  6.61 and 0.06 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:  70.8 and 100.0 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:  4.53 and 0.01 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:  25.83 and 0.01 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:  5.08 and 0.07 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:  7.82 and 100.0 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:  7.5 and 0.01 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:  66.19 and 0.01 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:  8.14 and 0.08 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:  64.14 and 100.0 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:  6.89 and 0.0 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:  53.24 and 0.0 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:  7.3 and 0.05 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:  17.17 and 100.0 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:  5.71 and 0.0 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:  37.0 and 0.0 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:  6.08 and 0.06 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:  72.31 and 100.0 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:  5.39 and 0.0 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:  44.16 and 0.0 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:  6.65 and 0.07 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:  -33.2 and 100.0 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:  7.58 and 0.01 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:  88.99 and 0.01 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:  9.43 and 0.08 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:  0.9 and 100.0 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:  5.48 and 0.0 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:  51.2 and 0.0 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:  7.16 and 0.07 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:  71.0 and 100.0 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:  2.76 and 0.0 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:  15.6 and 0.0 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:  3.95 and 0.04 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:  -20.62 and 100.0 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:  7.15 and 0.01 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:  86.04 and 0.01 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:  9.28 and 0.08 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:  81.57 and 100.0 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:  3.61 and 0.01 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:  14.3 and 0.01 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:  3.78 and 0.09 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:  5.31 and 100.0 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:  6.1 and 0.0 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:  51.76 and 0.0 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:  7.19 and 0.06 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:  68.11 and 100.0 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:  6.38 and 0.01 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:  52.4 and 0.01 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:  7.24 and 0.08 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:  -89.03 and 100.0 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:  9.85 and 0.01 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:  112.42 and 0.01 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:  10.6 and 0.07 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:  59.83 and 100.0 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:  6.14 and 0.01 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:  50.03 and 0.01 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:  7.07 and 0.08 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:  -79.12 and 100.0 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:  9.34 and 0.01 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:  129.56 and 0.01 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:  11.38 and 0.07 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:  -78.7 and 100.0 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:  10.42 and 0.0 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:  118.93 and 0.0 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:  10.91 and 0.06 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:  -66.59 and 100.0 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:  7.84 and 0.0 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:
(metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_gb= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_gb= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_gb= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_gb= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_gb= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_gb= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_gb= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_gb)#printing mean absolute error
print("Test_MSE ", Test_mse_gb)#printing mean squared error
print("Test_RMSE ", Test_rmse_gb)#printing root mean squared error
# Out:
# Test_Accuracy  83.74
# Test_MAE  3.371414639717839
# Test_MSE  12.613478522092718
# Test_RMSE  3.551545934109922

# %% [markdown]
# GradientBoosting is producing good accuracy = 83.74%. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(gb,X,Y,cv=5)
CV_Score_gb=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_gb)
# Out:
# [-0.11239706 -4.69713873  0.48915889  0.50588577  0.55310445]
# Cross Validation Score is  -0.6522773381100929

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_gb
# Out:
# 0.8373620247867701

# %%
CV_Score_gb
# Out:
# -0.6522773381100929

# %%
gb_Acc_vs_CV_Score=np.abs(Test_Accuracy_gb-CV_Score_gb)
print("Difference between Accuracy and Cross Validation Score = ",gb_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.4896393628968632

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is low (1.489) meaning that model is not having any overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.6 - XGBoost Regressor

# %% [markdown]
# # Best Random State

# %%
#Using XGBoost Regressor to get the best Random state
xgb=XGBRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    xgb.fit(x_train,y_train)
    pred_train=xgb.predict(x_train)
    pred_test=xgb.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are: ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are: ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are: ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are: ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:  18.39 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:  6.47 and 0.0 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:  60.03 and 0.0 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:  7.75 and 0.02 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:  46.96 and 100.0 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:  5.64 and 0.0 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:  74.08 and 0.0 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:  8.61 and 0.02 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:  -134.77 and 100.0 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:  7.57 and 0.0 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:  90.32 and 0.0 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:  9.5 and 0.02 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:  67.52 and 100.0 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:  6.87 and 0.0 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:  55.72 and 0.0 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:  7.46 and 0.02 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:  78.01 and 100.0 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:  3.37 and 0.0 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:  19.46 and 0.0 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:  4.41 and 0.02 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:  58.39 and 100.0 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:  4.96 and 0.0 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:  29.88 and 0.0 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:  5.47 and 0.02 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:  39.98 and 100.0 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:  7.66 and 0.0 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:  89.12 and 0.0 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:  9.44 and 0.02 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:  38.51 and 100.0 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:  4.15 and 0.0 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:  27.46 and 0.0 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:  5.24 and 0.02 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:  64.54 and 100.0 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:  5.48 and 0.0 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:  56.55 and 0.0 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:  7.52 and 0.02 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:  -30.8 and 100.0 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:  6.89 and 0.0 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:  87.38 and 0.0 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:  9.35 and 0.02 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:  20.43 and 100.0 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:  5.26 and 0.0 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:  41.11 and 0.0 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:  6.41 and 0.02 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:  70.5 and 100.0 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:  3.57 and 0.0 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:  15.87 and 0.0 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:  3.98 and 0.02 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:  -56.66 and 100.0 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:  8.64 and 0.0 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:  111.75 and 0.0 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:  10.57 and 0.02 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:  86.94 and 100.0 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:  2.87 and 0.0 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:  10.13 and 0.0 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:  3.18 and 0.02 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:  13.59 and 100.0 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:  5.89 and 0.0 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:  47.24 and 0.0 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:  6.87 and 0.02 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:  50.42 and 100.0 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:  6.72 and 0.0 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:  81.48 and 0.0 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:  9.03 and 0.02 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:  -26.55 and 100.0 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:  7.2 and 0.0 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:  75.26 and 0.0 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:  8.68 and 0.02 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:  1.19 and 100.0 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:  8.74 and 0.0 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:  123.08 and 0.0 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:  11.09 and 0.02 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:  13.65 and 100.0 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:  7.11 and 0.0 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:  62.46 and 0.0 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:  7.9 and 0.02 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:  -1.21 and 100.0 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:  6.36 and 0.0 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:  67.36 and 0.0 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:  8.21 and 0.02 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:  7.52 and 100.0 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:  5.4 and 0.0 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:  43.29 and 0.0 respectively
# At random state of :-  20 the root mean squared error of Testing and Training are:  6.58 and 0.02 respectively
#
#
# At random state of :- 21 Testing Accuracy and Training Accuracy are:  -12.95 and 100.0 respectively
# At random state of :-  21 the mean absolute error of Testing and Training are:  5.99 and 0.0 respectively
# At random state of :-  21 the mean squared error of Testing and Training are:  75.93 and 0.0 respectively
# At random state of :-  21 the root mean squared error of Testing and Training are:  8.71 and 0.02 respectively
#
#
# At random state of :- 22 Testing Accuracy and Training Accuracy are:  9.89 and 100.0 respectively
# At random state of :-  22 the mean absolute error of Testing and Training are:  6.59 and 0.0 respectively
# At random state of :-  22 the mean squared error of Testing and Training are:  69.31 and 0.0 respectively
# At random state of :-  22 the root mean squared error of Testing and Training are:  8.33 and 0.02 respectively
#
#
# At random state of :- 23 Testing Accuracy and Training Accuracy are:  68.6 and 100.0 respectively
# At random state of :-  23 the mean absolute error of Testing and Training are:  3.86 and 0.0 respectively
# At random state of :-  23 the mean squared error of Testing and Training are:  21.25 and 0.0 respectively
# At random state of :-  23 the root mean squared error of Testing and Training are:  4.61 and 0.02 respectively
#
#
# At random state of :- 24 Testing Accuracy and Training Accuracy are:  -158.82 and 100.0 respectively
# At random state of :-  24 the mean absolute error of Testing and Training are:  6.12 and 0.0 respectively
# At random state of :-  24 the mean squared error of Testing and Training are:  50.69 and 0.0 respectively
# At random state of :-  24 the root mean squared error of Testing and Training are:  7.12 and 0.02 respectively
#
#
# At random state of :- 25 Testing Accuracy and Training Accuracy are:  -13.38 and 100.0 respectively
# At random state of :-  25 the mean absolute error of Testing and Training are:  5.15 and 0.0 respectively
# At random state of :-  25 the mean squared error of Testing and Training are:  41.57 and 0.0 respectively
# At random state of :-  25 the root mean squared error of Testing and Training are:  6.45 and 0.02 respectively
#
#
# At random state of :- 26 Testing Accuracy and Training Accuracy are:  32.3 and 100.0 respectively
# At random state of :-  26 the mean absolute error of Testing and Training are:  5.76 and 0.0 respectively
# At random state of :-  26 the mean squared error of Testing and Training are:  43.42 and 0.0 respectively
# At random state of :-  26 the root mean squared error of Testing and Training are:  6.59 and 0.02 respectively
#
#
# At random state of :- 27 Testing Accuracy and Training Accuracy are:  -29.59 and 100.0 respectively
# At random state of :-  27 the mean absolute error of Testing and Training are:  9.18 and 0.0 respectively
# At random state of :-  27 the mean squared error of Testing and Training are:  114.36 and 0.0 respectively
# At random state of :-  27 the root mean squared error of Testing and Training are:  10.69 and 0.02 respectively
#
#
# At random state of :- 28 Testing Accuracy and Training Accuracy are:  51.63 and 100.0 respectively
# At random state of :-  28 the mean absolute error of Testing and Training are:  4.48 and 0.0 respectively
# At random state of :-  28 the mean squared error of Testing and Training are:  37.03 and 0.0 respectively
# At random state of :-  28 the root mean squared error of Testing and Training are:  6.08 and 0.02 respectively
#
#
# At random state of :- 29 Testing Accuracy and Training Accuracy are:  64.39 and 100.0 respectively
# At random state of :-  29 the mean absolute error of Testing and Training are:  5.46 and 0.0 respectively
# At random state of :-  29 the mean squared error of Testing and Training are:  41.98 and 0.0 respectively
# At random state of :-  29 the root mean squared error of Testing and Training are:  6.48 and 0.02 respectively
#
#
# At random state of :- 30 Testing Accuracy and Training Accuracy are:  50.29 and 100.0 respectively
# At random state of :-  30 the mean absolute error of Testing and Training are:  7.0 and 0.0 respectively
# At random state of :-  30 the mean squared error of Testing and Training are:  71.2 and 0.0 respectively
# At random state of :-  30 the root mean squared error of Testing and Training are:  8.44 and 0.02 respectively
#
#
# At random state of :- 31 Testing Accuracy and Training Accuracy are:  -304.51 and 100.0 respectively
# At random state of :-  31 the mean absolute error of Testing and Training are:  11.77 and 0.0 respectively
# At random state of :-  31 the mean squared error of Testing and Training are:
respectively
#
#
# At random state of :- 181 Testing Accuracy and Training Accuracy are:  39.22 and 100.0 respectively
# At random state of :-  181 the mean absolute error of Testing and Training are:  6.09 and 0.0 respectively
# At random state of :-  181 the mean squared error of Testing and Training are:  46.68 and 0.0 respectively
# At random state of :-  181 the root mean squared error of Testing and Training are:  6.83 and 0.02 respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:  53.06 and 100.0 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:  6.44 and 0.0 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:  54.56 and 0.0 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:  7.39 and 0.02 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:  71.93 and 100.0 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:  3.73 and 0.0 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:  20.66 and 0.0 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:  4.54 and 0.02 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:  61.64 and 100.0 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:  5.55 and 0.0 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:  36.79 and 0.0 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:  6.07 and 0.02 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:  -78.98 and 100.0 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:  9.42 and 0.0 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:  103.61 and 0.0 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:  10.18 and 0.02 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:  48.08 and 100.0 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:  5.34 and 0.0 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:  34.56 and 0.0 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:  5.88 and 0.02 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:  -27.52 and 100.0 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:  6.61 and 0.0 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:  55.54 and 0.0 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:  7.45 and 0.02 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:  -14.42 and 100.0 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:  6.46 and 0.0 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:  78.73 and 0.0 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:  8.87 and 0.02 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:  51.91 and 100.0 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:  8.33 and 0.0 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:  103.61 and 0.0 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:  10.18 and 0.02 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:  76.04 and 100.0 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:  4.61 and 0.0 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:  28.33 and 0.0 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:  5.32 and 0.02 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:  23.13 and 100.0 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:  6.69 and 0.0 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:  63.2 and 0.0 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:  7.95 and 0.02 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:  44.78 and 100.0 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:  6.23 and 0.0 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:  51.98 and 0.0 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:  7.21 and 0.02 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:  -176.33 and 100.0 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:  6.06 and 0.0 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:  44.6 and 0.0 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:  6.68 and 0.02 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:  50.65 and 100.0 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:  8.57 and 0.0 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:  80.89 and 0.0 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:  8.99 and 0.02 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:  52.5 and 100.0 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:  7.93 and 0.0 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:  94.16 and 0.0 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:  9.7 and 0.02 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:  54.07 and 100.0 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:  5.32 and 0.0 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:  50.93 and 0.0 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:  7.14 and 0.02 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:  -24.93 and 100.0 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:  8.05 and 0.0 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:  87.87 and 0.0 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:  9.37 and 0.02 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:  43.45 and 100.0 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:  6.64 and 0.0 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:  80.24 and 0.0 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:  8.96 and 0.02 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:  -65.6 and 100.0 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:  9.36 and 0.0 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:  133.44 and 0.0 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:  11.55 and 0.02 respectively

# %% [markdown]
# The best accuracy is 86.94% at random state 13

# %% [markdown]
# We have found best_random state value as 13. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=13,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
xgb=XGBRegressor()#Initializing...
xgb.fit(x_train,y_train)#Training...
pred_test=xgb.predict(x_test)#Prediciting using test data...
pred_train=xgb.predict(x_train)#Prediciting using training data...
Test_Accuracy_xgb=(metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_xgb= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_xgb= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_xgb= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_xgb= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_xgb= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_xgb= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_xgb= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_xgb)#printing mean absolute error
print("Test_MSE ", Test_mse_xgb)#printing mean squared error
print("Test_RMSE ", Test_rmse_xgb)#printing root mean squared error
# Out:
# Test_Accuracy  86.94
# Test_MAE  2.8710734049479165
# Test_MSE  10.13111073919572
# Test_RMSE  3.182940580531738

# %% [markdown]
# XGBoost is producing good accuracy = 86.94%. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(xgb,X,Y,cv=5)
CV_Score_xgb=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_xgb)
# Out:
# [-0.40498787 -5.48724122  0.25650398  0.65070692  0.74980407]
# Cross Validation Score is  -0.8470428251264448

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_xgb
# Out:
# 0.869369632302634

# %%
CV_Score_xgb
# Out:
# -0.8470428251264448

# %%
xgb_Acc_vs_CV_Score=np.abs(Test_Accuracy_xgb-CV_Score_xgb)
print("Difference between Accuracy and Cross Validation Score = ",xgb_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.7164124574290787

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is low (1.71) meaning that model is not having any overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.7 - ExtraTrees Regressor

# %% [markdown]
# # Best Random State

# %%
#Using ExtraTree Regressor to get the best Random state
ex=ExtraTreesRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    ex.fit(x_train,y_train)
    pred_train=ex.predict(x_train)
    pred_test=ex.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are: ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are: ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are: ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are: ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:  47.23 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:  4.79 and 0.0 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:  38.81 and 0.0 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:  6.23 and 0.0 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:  47.53 and 100.0 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:  6.08 and 0.0 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:  73.28 and 0.0 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:  8.56 and 0.0 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:  -142.28 and 100.0 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:  7.73 and 0.0 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:  93.21 and 0.0 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:  9.65 and 0.0 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:  60.09 and 100.0 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:  7.9 and 0.0 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:  68.47 and 0.0 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:  8.27 and 0.0 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:  72.38 and 100.0 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:  3.76 and 0.0 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:  24.43 and 0.0 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:  4.94 and 0.0 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:  51.05 and 100.0 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:  5.49 and 0.0 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:  35.15 and 0.0 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:  5.93 and 0.0 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:  27.59 and 100.0 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:  8.37 and 0.0 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:  107.51 and 0.0 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:  10.37 and 0.0 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:  41.78 and 100.0 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:  4.74 and 0.0 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:  26.01 and 0.0 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:  5.1 and 0.0 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:  44.97 and 100.0 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:  8.02 and 0.0 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:  87.76 and 0.0 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:  9.37 and 0.0 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:  3.37 and 100.0 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:  7.12 and 0.0 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:  64.55 and 0.0 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:  8.03 and 0.0 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:  31.47 and 100.0 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:  4.08 and 0.0 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:  35.41 and 0.0 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:  5.95 and 0.0 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:  23.89 and 100.0 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:  5.46 and 0.0 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:  40.95 and 0.0 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:  6.4 and 0.0 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:  4.55 and 100.0 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:  6.51 and 0.0 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:  68.09 and 0.0 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:  8.25 and 0.0 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:  70.96 and 100.0 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:  3.47 and 0.0 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:  22.52 and 0.0 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:  4.75 and 0.0 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:  50.63 and 100.0 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:  4.53 and 0.0 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:  26.99 and 0.0 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:  5.19 and 0.0 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:  54.42 and 100.0 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:  7.1 and 0.0 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:  74.9 and 0.0 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:  8.65 and 0.0 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:  -10.36 and 100.0 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:  5.94 and 0.0 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:  65.63 and 0.0 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:  8.1 and 0.0 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:  46.72 and 100.0 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:  6.95 and 0.0 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:  66.36 and 0.0 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:  8.15 and 0.0 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:  30.69 and 100.0 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:  6.14 and 0.0 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:  50.13 and 0.0 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:  7.08 and 0.0 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:  0.45 and 100.0 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:  6.76 and 0.0 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:  66.26 and 0.0 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:  8.14 and 0.0 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:  37.3 and 100.0 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:  4.51 and 0.0 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:  29.35 and 0.0 respectively
# At random state of :-  20 the root mean squared error of Testing and Training are:  5.42 and 0.0 respectively
#
#
# At random state of :- 21 Testing Accuracy and Training Accuracy are:  21.19 and 100.0 respectively
# At random state of :-  21 the mean absolute error of Testing and Training are:  6.24 and 0.0 respectively
# At random state of :-  21 the mean squared error of Testing and Training are:  52.98 and 0.0 respectively
# At random state of :-  21 the root mean squared error of Testing and Training are:  7.28 and 0.0 respectively
#
#
# At random state of :- 22 Testing Accuracy and Training Accuracy are:  5.31 and 100.0 respectively
# At random state of :-  22 the mean absolute error of Testing and Training are:  7.46 and 0.0 respectively
# At random state of :-  22 the mean squared error of Testing and Training are:  72.83 and 0.0 respectively
# At random state of :-  22 the root mean squared error of Testing and Training are:  8.53 and 0.0 respectively
#
#
# At random state of :- 23 Testing Accuracy and Training Accuracy are:  36.26 and 100.0 respectively
# At random state of :-  23 the mean absolute error of Testing and Training are:  4.96 and 0.0 respectively
# At random state of :-  23 the mean squared error of Testing and Training are:  43.13 and 0.0 respectively
# At random state of :-  23 the root mean squared error of Testing and Training are:  6.57 and 0.0 respectively
#
#
# At random state of :- 24 Testing Accuracy and Training Accuracy are:  19.27 and 100.0 respectively
# At random state of :-  24 the mean absolute error of Testing and Training are:  3.23 and 0.0 respectively
# At random state of :-  24 the mean squared error of Testing and Training are:  15.81 and 0.0 respectively
# At random state of :-  24 the root mean squared error of Testing and Training are:  3.98 and 0.0 respectively
#
#
# At random state of :- 25 Testing Accuracy and Training Accuracy are:  43.63 and 100.0 respectively
# At random state of :-  25 the mean absolute error of Testing and Training are:  3.84 and 0.0 respectively
# At random state of :-  25 the mean squared error of Testing and Training are:  20.67 and 0.0 respectively
# At random state of :-  25 the root mean squared error of Testing and Training are:  4.55 and 0.0 respectively
#
#
# At random state of :- 26 Testing Accuracy and Training Accuracy are:  34.56 and 100.0 respectively
# At random state of :-  26 the mean absolute error of Testing and Training are:  6.0 and 0.0 respectively
# At random state of :-  26 the mean squared error of Testing and Training are:  41.97 and 0.0 respectively
# At random state of :-  26 the root mean squared error of Testing and Training are:  6.48 and 0.0 respectively
#
#
# At random state of :- 27 Testing Accuracy and Training Accuracy are:  4.19 and 100.0 respectively
# At random state of :-  27 the mean absolute error of Testing and Training are:  7.94 and 0.0 respectively
# At random state of :-  27 the mean squared error of Testing and Training are:  84.55 and 0.0 respectively
# At random state of :-  27 the root mean squared error of Testing and Training are:  9.2 and 0.0 respectively
#
#
# At random state of :- 28 Testing Accuracy and Training Accuracy are:  65.87 and 100.0 respectively
# At random state of :-  28 the mean absolute error of Testing and Training are:  4.28 and 0.0 respectively
# At random state of :-  28 the mean squared error of Testing and Training are:  26.13 and 0.0 respectively
# At random state of :-  28 the root mean squared error of Testing and Training are:  5.11 and 0.0 respectively
#
#
# At random state of :- 29 Testing Accuracy and Training Accuracy are:  31.26 and 100.0 respectively
# At random state of :-  29 the mean absolute error of Testing and Training are:  7.55 and 0.0 respectively
# At random state of :-  29 the mean squared error of Testing and Training are:  81.04 and 0.0 respectively
# At random state of :-  29 the root mean squared error of Testing and Training are:  9.0 and 0.0 respectively
#
#
# At random state of :- 30 Testing Accuracy and Training Accuracy are:  42.86 and 100.0 respectively
# At random state of :-  30 the mean absolute error of Testing and Training are:  7.45 and 0.0 respectively
# At random state of :-  30 the mean squared error of Testing and Training are:  81.84 and 0.0 respectively
# At random state of :-  30 the root mean squared error of Testing and Training are:  9.05 and 0.0 respectively
#
#
# At random state of :- 31 Testing Accuracy and Training Accuracy are:  -94.84 and 100.0 respectively
# At random state of :-  31 the mean absolute error of Testing and Training are:  8.73 and 0.0 respectively
# At random state of :-  31 the mean squared error of Testing and Training are:  95.74 and 0.0 respectively
# At random state of :-  31 the root mean squared error of Testing and Training are:  9.78 and 0.0 respectively
#
#
# At random state of :- 32 Testing Accuracy and Training Accuracy are:  54.7 and 100.0 respectively
# At random state of :-  32 the mean absolute error of Testing and Training are:  5.35 and 0.0 respectively
# At random state of :-  32 the mean squared error of Testing and Training are:  41.77 and 0.0 respectively
# At random state of :-  32 the root mean squared error of Testing and Training are:  6.46 and 0.0 respectively
#
#
# At random state of :- 33 Testing Accuracy and Training Accuracy are:  49.65 and 100.0 respectively
# At random state of :-  33 the mean absolute error of Testing and Training are:  5.52 and 0.0 respectively
# At random state of :-  33 the mean squared error of Testing and Training are:  39.73 and 0.0 respectively
# At random state of :-  33 the root mean squared error of Testing and Training are:  6.3 and 0.0 respectively
#
#
# At random state of :- 34 Testing Accuracy and Training Accuracy are:  19.09 and 100.0 respectively
# At random state of :-  34 the mean absolute error of Testing and Training are:  5.86 and 0.0 respectively
# At random state of :-  34 the mean squared error of Testing and Training are:  52.8 and 0.0 respectively
# At random state of :-  34 the root mean squared error of Testing and Training are:  7.27 and 0.0 respectively
#
#
# At random state of :- 35 Testing Accuracy and Training Accuracy are:  62.12 and 100.0 respectively
# At random state of :-  35 the mean absolute error of Testing and Training are:  6.79 and 0.0 respectively
# At random state of :-  35 the mean squared error of Testing and Training are:  59.31 and 0.0 respectively
# At random state of :-  35 the root mean squared error of Testing and Training are:  7.7 and 0.0 respectively
#
#
# At random state of :- 36 Testing Accuracy and Training Accuracy are:  -58.97 and 100.0 respectively
# At random state of :-  36 the mean absolute error of Testing and Training are:  9.44 and 0.0 respectively
# At random state of :-  36 the mean squared error of Testing and Training are:  130.18 and 0.0 respectively
# At random state of :-  36 the root mean squared error of Testing and Training are:  11.41 and 0.0 respectively
#
#
# At random state of :- 37 Testing Accuracy and Training Accuracy are:  -114.82 and 100.0 respectively
# At random state of :-  37 the mean absolute error of Testing and Training are:  8.86 and 0.0 respectively
# At random state of :-  37 the mean squared error of Testing and Training are:  96.97 and 0.0 respectively
# At random state of :-  37 the root mean squared error of Testing and Training are:  9.85 and 0.0 respectively
#
#
# At random state of :- 38 Testing Accuracy and Training Accuracy are:  28.37 and 100.0 respectively
# At random state of :-  38 the mean absolute error of Testing and Training are:  5.51 and 0.0 respectively
# At random state of :-  38 the mean squared error of Testing and Training are:  42.68 and 0.0 respectively
# At random state of :-  38 the root mean squared error of Testing and Training are:  6.53 and 0.0 respectively
#
#
# At random state of :- 39 Testing Accuracy and Training Accuracy are:  12.29 and 100.0 respectively
# At random state of :-  39 the mean absolute error of Testing and Training are:  6.98 and 0.0 respectively
# At random state of :-  39 the mean squared error of Testing and Training are:  70.39 and 0.0 respectively
# At random state of :-  39 the root mean squared error of Testing and Training are:  8.39 and 0.0 respectively
#
#
# At random state of :- 40 Testing Accuracy and Training Accuracy are:  3.31 and 100.0 respectively
# At random state of :-  40 the mean absolute error of Testing and Training are:  9.62 and 0.0 respectively
# At random state of :-  40 the mean squared error of Testing and Training are:  124.41 and 0.0 respectively
# At random state of :-  40 the root mean squared error of Testing and Training are:  11.15 and 0.0 respectively
#
#
# At random state of :- 41 Testing Accuracy and Training Accuracy are:  33.68 and 100.0 respectively
# At random state of :-  41 the mean absolute error of Testing and Training are:  6.25 and 0.0 respectively
# At random state of :-  41 the mean squared error of Testing and Training are:  54.99 and 0.0 respectively
# At random state of :-  41 the root mean squared error of Testing and Training are:  7.42 and 0.0 respectively
#
#
# At random state of :- 42 Testing Accuracy and Training Accuracy are:  37.79 and 100.0 respectively
# At random state of :-  42 the mean absolute error of Testing and Training are:  6.24 and 0.0 respectively
# At random state of :-  42 the mean squared error of Testing and Training are:  59.93 and 0.0 respectively
# At random state of :-  42 the root mean squared error of Testing and Training are:  7.74 and 0.0 respectively
#
#
# At random state of :- 43 Testing Accuracy and Training Accuracy are:  -16.11 and 100.0 respectively
# At random state of :-  43 the mean absolute error of Testing and Training are:  6.07 and 0.0 respectively
# At random state of :-  43 the mean squared error of Testing and Training are:  58.99 and 0.0 respectively
# At random state of :-  43 the root mean squared error of Testing and Training are:  7.68 and 0.0 respectively
#
#
# At random state of :- 44 Testing Accuracy and Training Accuracy are:  26.92 and 100.0 respectively
# At random state of :-  44 the mean absolute error of Testing and Training are:  4.85 and 0.0 respectively
# At random state of :-  44 the mean squared error of Testing and Training are:  36.54 and 0.0 respectively
# At random state of :-  44 the root mean squared error of Testing and Training are:  6.04 and 0.0 respectively
#
#
# At random state of :- 45 Testing Accuracy and Training Accuracy are:  10.08 and 100.0 respectively
# At random state of :-  45 the mean absolute error of Testing and Training are:  6.53 and 0.0 respectively
# At random state of :-  45 the mean squared error of Testing and Training are:  55.35 and 0.0 respectively
# At random state of :-  45 the root mean squared error of Testing and Training are:  7.44 and 0.0 respectively
#
#
# At random state of :- 46 Testing Accuracy and Training Accuracy are:  55.84 and 100.0 respectively
# At random state of :-  46 the mean absolute error of Testing and Training are:  4.82 and 0.0 respectively
# At random state of :-  46 the mean squared error of Testing and Training are:  26.85 and 0.0 respectively
# At random state of :-  46 the root mean squared error of Testing and Training are:  5.18 and 0.0 respectively
#
#
# At random state of :- 47 Testing Accuracy and Training Accuracy are:  39.41 and 100.0 respectively
# At random state of :-  47 the mean absolute error of Testing and Training are:  7.29 and 0.0 respectively
# At random state of :-  47 the mean squared error of Testing and Training are:  76.48 and 0.0 respectively
# At random state of :-  47 the root mean squared error of Testing and Training are:  8.75 and 0.0 respectively
#
#
# At random state of :- 48 Testing Accuracy and Training Accuracy are:  59.27 and 100.0 respectively
# At random state of :-  48 the mean absolute error of Testing and Training are:  4.85 and 0.0 respectively
# At random state of :-  48 the mean squared error of Testing and Training are:  33.89 and 0.0 respectively
# At random state of :-  48 the root mean squared error of Testing and Training are:  5.82 and 0.0 respectively
#
#
# At random state of :- 49 Testing Accuracy and Training Accuracy are:  -191.75 and 100.0 respectively
# At random state of :-  49 the mean absolute error of Testing and Training are:  13.1 and 0.0 respectively
# At random state of :-  49 the mean squared error of Testing and Training are:  226.02 and 0.0 respectively
# At random state of :-  49 the root mean squared error of Testing and Training are:  15.03 and 0.0 respectively
#
#
# At random state of :- 50 Testing Accuracy and Training Accuracy are:  30.57 and 100.0 respectively
# At random state of :-  50 the mean absolute error of Testing and Training are:  6.18 and 0.0 respectively
# At random state of :-  50 the mean squared error of Testing and Training are:  44.13 and 0.0 respectively
# At random state of :-  50 the root mean squared error of Testing and Training are:  6.64 and 0.0 respectively
#
#
# At random state of :- 51 Testing Accuracy and Training Accuracy are:  30.71 and 100.0 respectively
# At random state of :-  51 the mean absolute error of Testing and Training are:  6.25 and 0.0 respectively
# At random state of :-  51 the mean squared error of Testing and Training are:  57.46 and 0.0 respectively
# At random state of :-  51 the root mean squared error of Testing and Training are:  7.58 and 0.0 respectively
#
#
# At random state of :- 52 Testing Accuracy and Training Accuracy are:  33.27 and 100.0 respectively
# At random state of :-  52 the mean absolute error of Testing and Training are:  4.22 and 0.0 respectively
# At random state of :-  52 the mean squared error of Testing and Training are:  31.01 and 0.0 respectively
# At random state of :-  52 the root mean squared error of Testing and Training are:  5.57 and 0.0 respectively
#
#
# At random state of :- 53 Testing Accuracy and Training Accuracy are:  81.8 and 100.0 respectively
# At random state of :-  53 the mean absolute error of Testing and Training are:  2.89 and 0.0 respectively
# At random state of :-  53 the mean squared error of Testing and Training are:  16.1 and 0.0 respectively
# At random state of :-  53 the root mean squared error of Testing and Training are:  4.01 and 0.0 respectively
#
#
# At random state of :- 54 Testing Accuracy and Training Accuracy are:  39.17 and 100.0 respectively
# At random state of :-  54 the mean absolute error of Testing and Training are:  3.34 and 0.0 respectively
# At random state of :-  54 the mean squared error of Testing and Training are:  18.99 and 0.0 respectively
# At random state of :-  54 the root mean squared error of Testing and Training are:  4.36 and 0.0 respectively
#
#
# At random state of :- 55 Testing Accuracy and Training Accuracy are:  47.74 and 100.0 respectively
# At random state of :-  55 the mean absolute error of Testing and Training are:  4.7 and 0.0 respectively
# At random state of :-  55 the mean squared error of Testing and Training are:  38.22 and 0.0 respectively
# At random state of :-  55 the root mean squared error of Testing and Training are:  6.18 and 0.0 respectively
#
#
# At random state of :- 56 Testing Accuracy and Training Accuracy are:  -2.9 and 100.0 respectively
# At random state of :-  56 the mean absolute error of Testing and Training are:  7.13 and 0.0 respectively
# At random state of :-  56 the mean squared error of Testing and Training are:  63.94 and 0.0 respectively
# At random state of :-  56 the root mean squared error of Testing and Training are:  8.0 and 0.0 respectively
#
#
# At random state of :- 57 Testing Accuracy and Training Accuracy are:  51.07 and 100.0 respectively
# At random state of :-  57 the mean absolute error of Testing and Training are:  8.15 and 0.0 respectively
# At random state of :-  57 the mean squared error of Testing and Training are:  68.99 and 0.0 respectively
# At random state of :-  57 the root mean squared error of Testing and Training are:  8.31 and 0.0 respectively
#
#
# At random state of :- 58 Testing Accuracy and Training Accuracy are:  -2.95 and 100.0 respectively
# At random state of :-  58 the mean absolute error of Testing and Training are:  8.54 and 0.0 respectively
# At random state of :-  58 the mean squared error of Testing and Training are:  91.17 and 0.0 respectively
# At random state of :-  58 the root mean squared error of Testing and Training are:  9.55 and 0.0 respectively
#
#
# At random state of :- 59 Testing Accuracy and Training Accuracy are:  12.23 and 100.0 respectively
# At random state of :-  59 the mean absolute error of Testing and Training are:  5.67 and 0.0 respectively
# At random state of :-  59 the mean squared error of Testing and Training are:  46.93 and 0.0 respectively
# At random state of :-  59 the root mean squared error of Testing and Training are:  6.85 and 0.0 respectively
#
#
# At random state of :- 60 Testing Accuracy and Training Accuracy are:  37.22 and 100.0 respectively
# At random state of :-  60 the mean absolute error of Testing and Training are:  6.38 and 0.0 respectively
# At random state of :-  60 the mean squared error of Testing and Training are:  61.19 and 0.0 respectively
# At random state of :-  60 the root mean squared error of Testing and Training are:  7.82 and 0.0 respectively
#
#
# At random state of :- 61 Testing Accuracy and Training Accuracy are:  49.4 and 100.0 respectively
# At random state of :-  61 the mean absolute error of Testing and Training are:  6.65 and 0.0 respectively
# At random state of :-  61 the mean squared error of Testing and Training are:  54.94 and 0.0 respectively
# At random state of :-  61 the root mean squared error of Testing and Training are:  7.41 and 0.0 respectively
#
#
# At random state of :- 62 Testing Accuracy and Training Accuracy are:  40.73 and 100.0 respectively
# At random state of :-  62 the mean absolute error of Testing and Training are:  5.25 and 0.0 respectively
# At random state of :-  62 the mean squared error of Testing and Training are:  42.95 and 0.0 respectively
# At random state of :-  62 the root mean squared error of Testing and Training are:  6.55 and 0.0 respectively
#
#
# At random state of :- 63 Testing Accuracy and Training Accuracy are:  13.5 and 100.0 respectively
# At random state of :-  63 the mean absolute error of Testing and Training are:  7.27 and 0.0 respectively
# At random state of :-  63 the mean squared error of Testing and Training are:  79.41 and 0.0 respectively
# At random state of :-  63 the root mean squared error of Testing and Training are:  8.91 and 0.0 respectively
#
#
# At random state of :- 64 Testing Accuracy and Training Accuracy are:  43.04 and 100.0 respectively
# At random state of :-  64 the mean absolute error of Testing and Training are:  7.03 and 0.0 respectively
# At random state of :-  64 the mean squared error of Testing and Training are:  66.58 and 0.0 respectively
# At random state of :-  64 the root mean squared error of Testing and Training are:  8.16 and 0.0 respectively
#
#
# At random state of :- 65 Testing Accuracy and Training Accuracy are:  62.97 and 100.0 respectively
# At random state of :-  65 the mean absolute error of Testing and Training are:  5.88 and 0.0 respectively
# At random state of :-  65 the mean squared error of Testing and Training are:  42.55 and 0.0 respectively
# At random state of :-  65 the root mean squared error of Testing and Training are:  6.52 and 0.0 respectively
#
#
# At random state of :- 66 Testing Accuracy and Training Accuracy are:  35.44 and 100.0 respectively
# At random state of :-  66 the mean absolute error of Testing and Training are:  5.41 and 0.0 respectively
# At random state of :-  66 the mean squared error of Testing and Training are:  44.33 and 0.0 respectively
# At random state of :-  66 the root mean squared error of Testing and Training are:  6.66 and 0.0 respectively
#
#
# At random state of :- 67 Testing Accuracy and Training Accuracy are:  59.44 and 100.0 respectively
# At random state of :-  67 the mean absolute error of Testing and Training are:  7.75 and 0.0 respectively
# At random state of :-  67 the mean squared error of Testing and Training are:  65.16 and 0.0 respectively
# At random state of :-  67 the root mean squared error of Testing and Training are:  8.07 and 0.0 respectively
#
#
# At random state of :- 68 Testing Accuracy and Training Accuracy are:  68.96 and 100.0 respectively
# At random state of :-  68 the mean absolute error of Testing and Training are:  4.11 and 0.0 respectively
# At random state of :-  68 the mean squared error of Testing and Training are:  25.76 and 0.0 respectively
# At random state of :-  68 the root mean squared error of Testing and Training are:  5.08 and 0.0 respectively
#
#
# At random state of :- 69 Testing Accuracy and Training Accuracy are:  5.27 and 100.0 respectively
# At random state of :-  69 the mean absolute error of Testing and Training are:  9.94 and 0.0 respectively
# At random state of :-  69 the mean squared error of Testing and Training are:  148.33 and 0.0 respectively
# At random state of :-  69 the root mean squared error of Testing and Training are:  12.18 and 0.0 respectively
#
#
# At random state of :- 70 Testing Accuracy and Training Accuracy are:  51.57 and 100.0 respectively
# At random state of :-  70 the mean absolute error of Testing and Training are:  5.65 and 0.0 respectively
# At random state of :-  70 the mean squared error of Testing and Training are:  33.36 and 0.0 respectively
# At random state of :-  70 the root mean squared error of Testing and Training are:  5.78 and 0.0 respectively
#
#
# At random state of :- 71 Testing Accuracy and Training Accuracy are:  -252.94 and 100.0 respectively
# At random state of :-  71 the mean absolute error of Testing and Training are:  6.87 and 0.0 respectively
# At random state of :-  71 the mean squared error of Testing and Training are:  65.59 and 0.0 respectively
# At random state of :-  71 the root mean squared error of Testing and Training are:  8.1 and 0.0 respectively
#
#
# At random state of :- 72 Testing Accuracy and Training Accuracy are:  31.57 and 100.0 respectively
# At random state of :-  72 the mean absolute error of Testing and Training are:  3.66 and 0.0 respectively
# At random state of :-  72 the mean squared error of Testing and Training are:  20.4 and 0.0 respectively
# At random state of :-  72 the root mean squared error of Testing and Training are:  4.52 and 0.0 respectively
#
#
# At random state of :- 73 Testing Accuracy and Training Accuracy are:  55.85 and 100.0 respectively
# At random state of :-  73 the mean absolute error of Testing and Training are:  7.07 and 0.0 respectively
# At random state of :-  73 the mean squared error of Testing and Training are:  58.68 and 0.0 respectively
# At random state of :-  73 the root mean squared error of Testing and Training are:  7.66 and 0.0 respectively
#
#
# At random state of :- 74 Testing Accuracy and Training Accuracy are:  -20.19 and 100.0 respectively
# At random state of :-  74 the mean absolute error of Testing and Training are:  4.44 and 0.0 respectively
# At random state of :-  74 the mean squared error of Testing and Training are:  39.13 and 0.0 respectively
# At random state of :-  74 the root mean squared error of Testing and Training are:  6.26 and 0.0 respectively
#
#
# At random state of :- 75 Testing Accuracy and Training Accuracy are:  53.85 and 100.0 respectively
# At random state of :-  75 the mean absolute error of Testing and Training are:  6.17 and 0.0 respectively
# At random state of :-  75 the mean squared error of Testing and Training are:  62.36 and 0.0 respectively
# At random state of :-  75 the root mean squared error of Testing and Training are:  7.9 and 0.0 respectively
#
#
# At random state of :- 76 Testing Accuracy and Training Accuracy are:  60.09 and 100.0 respectively
# At random state of :-  76 the mean absolute error of Testing and Training are:  6.8 and 0.0 respectively
# At random state of :-  76 the mean squared error of Testing and Training are:  57.56 and 0.0 respectively
# At random state of :-  76 the root mean squared error of Testing and Training are:  7.59 and 0.0 respectively
#
#
# At random state of :- 77 Testing Accuracy and Training Accuracy are:  36.79 and 100.0 respectively
# At random state of :-  77 the mean absolute error of Testing and Training are:  4.49 and 0.0 respectively
# At random state of :-  77 the mean squared error of Testing and Training are:  35.4 and 0.0 respectively
# At random state of :-  77 the root mean squared error of Testing and Training are:  5.95 and 0.0 respectively
#
#
# At random state of :- 78 Testing Accuracy and Training Accuracy are:  29.04 and 100.0 respectively
# At random state of :-  78 the mean absolute error of Testing and Training are:  7.13 and 0.0 respectively
# At random state of :-  78 the mean squared error of Testing and Training are:  59.05 and 0.0 respectively
# At random state of :-  78 the root mean squared error of Testing and Training are:  7.68 and 0.0 respectively
#
#
# At random state of :- 79 Testing Accuracy and Training Accuracy are:  31.42 and 100.0 respectively
# At random state of :-  79 the mean absolute error of Testing and Training are:  8.16 and 0.0 respectively
# At random state of :-  79 the mean squared error of Testing and Training are:  87.42 and 0.0 respectively
# At random state of :-  79 the root mean squared error of Testing and Training are:  9.35 and 0.0 respectively
#
#
# At random state of :- 80 Testing Accuracy and Training Accuracy are:  53.14 and 100.0 respectively
# At random state of :-  80 the mean absolute error of Testing and Training are:  4.76 and 0.0 respectively
# At random state of :-  80 the mean squared error of Testing and Training are:  53.02 and 0.0 respectively
# At random state of :-  80 the root mean squared error of Testing and Training are:  7.28 and 0.0 respectively
#
#
# At random state of :- 81 Testing Accuracy and Training Accuracy are:  47.42 and 100.0 respectively
# At random state of :-  81 the mean absolute error of Testing and Training are:  6.59 and 0.0 respectively
# At random state of :-  81 the mean squared error of Testing and Training are:  61.99 and 0.0 respectively
# At random state of :-  81 the root mean squared error of Testing and Training are:  7.87 and 0.0 respectively
#
#
# At random state of :- 82 Testing Accuracy and Training Accuracy are:  81.09 and 100.0 respectively
# At random state of :-  82 the mean absolute error of Testing and Training are:  3.23 and 0.0 respectively
# At random state of :-  82 the mean squared error of Testing and Training are:  13.83 and 0.0 respectively
# At random state of :-  82 the root mean squared error of Testing and Training are:  3.72 and 0.0 respectively
#
#
# At random state of :- 83 Testing Accuracy and Training Accuracy are:  65.96 and 100.0 respectively
# At random state of :-  83 the mean absolute error of Testing and Training are:  5.45 and 0.0 respectively
# At random state of :-  83 the mean squared error of Testing and Training are:  38.54 and 0.0 respectively
# At random state of :-  83 the root mean squared error of Testing and Training are:  6.21 and 0.0 respectively
#
#
# At random state of :- 84 Testing Accuracy and Training Accuracy are:  32.64 and 100.0 respectively
# At random state of :-  84 the mean absolute error of Testing and Training are:  4.6 and 0.0 respectively
# At random state of :-  84 the mean squared error of Testing and Training are:  33.6 and 0.0 respectively
# At random state of :-  84 the root mean squared error of Testing and Training are:  5.8 and 0.0 respectively
#
#
# At random state of :- 85 Testing Accuracy and Training Accuracy are:  28.13 and 100.0 respectively
# At random state of :-  85 the mean absolute error of Testing and Training are:  7.95 and 0.0 respectively
# At random state of :-  85 the mean squared error of Testing and Training are:  93.3 and 0.0 respectively
# At random state of :-  85 the root mean squared error of Testing and Training are:  9.66 and 0.0 respectively
#
#
# At random state of :- 86 Testing Accuracy and Training Accuracy are:  23.83 and 100.0 respectively
# At random state of :-  86 the mean absolute error of Testing and Training are:  4.9 and 0.0 respectively
# At random state of :-  86 the mean squared error of Testing and Training are:  29.3 and 0.0 respectively
# At random state of :-  86 the root mean squared error of Testing and Training are:  5.41 and 0.0 respectively
#
#
# At random state of :- 87 Testing Accuracy and Training Accuracy are:  18.34 and 100.0 respectively
# At random state of :-  87 the mean absolute error of Testing and Training are:  4.58 and 0.0 respectively
# At random state of :-  87 the mean squared error of Testing and Training are:  41.04 and 0.0 respectively
# At random state of :-  87 the root mean squared error of Testing and Training are:  6.41 and 0.0 respectively
#
#
# At random state of :- 88 Testing Accuracy and Training Accuracy are:  54.07 and 100.0 respectively
# At random state of :-  88 the mean absolute error of Testing and Training are:  3.91 and 0.0 respectively
# At random state of :-  88 the mean squared error of Testing and Training are:  20.17 and 0.0 respectively
# At random state of :-  88 the root mean squared error of Testing and Training are:  4.49 and 0.0 respectively
#
#
# At random state of :- 89 Testing Accuracy and Training Accuracy are:  27.71 and 100.0 respectively
# At random state of :-  89 the mean absolute error of Testing and Training are:  5.95 and 0.0 respectively
# At random state of :-  89 the mean squared error of Testing and Training are:  58.8 and 0.0 respectively
# At random state of :-  89 the root mean squared error of Testing and Training are:  7.67 and 0.0 respectively
#
#
# At random state of :- 90 Testing Accuracy and Training Accuracy are:  31.07 and 100.0 respectively
# At random state of :-  90 the mean absolute error of Testing and Training are:  5.61 and 0.0 respectively
# At random state of :-  90 the mean squared error of Testing and Training are:  42.6 and 0.0 respectively
# At random state of :-  90 the root mean squared error of Testing and Training are:  6.53 and 0.0 respectively
#
#
# At random state of :- 91 Testing Accuracy and Training Accuracy are:  15.6 and 100.0 respectively
# At random state of :-  91 the mean absolute error of Testing and Training are:  9.38 and 0.0 respectively
# At random state of :-  91 the mean squared error of Testing and Training are:  94.08 and 0.0 respectively
# At random state of :-  91 the root mean squared error of Testing and Training are:  9.7 and 0.0 respectively
#
#
# At random state of :- 92 Testing Accuracy and Training Accuracy are:  23.01 and 100.0 respectively
# At random state of :-  92 the mean absolute error of Testing and Training are:  6.08 and 0.0 respectively
# At random state of :-  92 the mean squared error of Testing and Training are:  55.6 and 0.0 respectively
# At random state of :-  92 the root mean squared error of Testing and Training are:  7.46 and 0.0 respectively
#
#
# At random state of :- 93 Testing Accuracy and Training Accuracy are:  34.14 and 100.0 respectively
# At random state of :-  93 the mean absolute error of Testing and Training are:  5.73 and 0.0 respectively
# At random state of :-  93 the mean squared error of Testing and Training are:  43.62 and 0.0 respectively
# At random state of :-  93 the root mean squared error of Testing and Training are:  6.6 and 0.0 respectively
#
#
# At random state of :- 94 Testing Accuracy and Training Accuracy are:  55.71 and 100.0 respectively
# At random state of :-  94 the mean absolute error of Testing and Training are:  3.95 and 0.0 respectively
# At random state of :-  94 the mean squared error of Testing and Training are:  26.52 and 0.0 respectively
# At random state of :-  94 the root mean squared error of Testing and Training are:  5.15 and 0.0 respectively
#
#
# At random state of :- 95 Testing Accuracy and Training Accuracy are:  40.08 and 100.0 respectively
# At random state of :-  95 the mean absolute error of Testing and Training are:  7.97 and 0.0 respectively
# At random state of :-  95 the mean squared error of Testing and Training are:  85.81 and 0.0 respectively
# At random state of :-  95 the root mean squared error of Testing and Training are:  9.26 and 0.0 respectively
#
#
# At random state of :- 96 Testing Accuracy and Training Accuracy are:  41.52 and 100.0 respectively
# At random state of :-  96 the mean absolute error of Testing and Training are:  7.85 and 0.0 respectively
# At random state of :-  96 the mean squared error of Testing and Training are:  72.71 and 0.0 respectively
# At random state of :-  96 the root mean squared error of Testing and Training are:  8.53 and 0.0 respectively
#
#
# At random state of :- 97 Testing Accuracy and Training Accuracy are:  43.76 and 100.0 respectively
# At random state of :-  97 the mean absolute error of Testing and Training are:  7.01 and 0.0 respectively
# At random state of :-  97 the mean squared error of Testing and Training are:  64.57 and 0.0 respectively
# At random state of :-  97 the root mean squared error of Testing and Training are:  8.04 and 0.0 respectively
#
#
# At random state of :- 98 Testing Accuracy and Training Accuracy are:  -21.43 and 100.0 respectively
# At random state of :-  98 the mean absolute error of Testing and Training are:  11.28 and 0.0 respectively
# At random state of :-  98 the mean squared error of Testing and Training are:  161.78 and 0.0 respectively
# At random state of :-  98 the root mean squared error of Testing and Training are:  12.72 and 0.0 respectively
#
#
# At random state of :- 99 Testing Accuracy and Training Accuracy are:  51.6 and 100.0 respectively
# At random state of :-  99 the mean absolute error of Testing and Training are:  7.53 and 0.0 respectively
# At random state of :-  99 the mean squared error of Testing and Training are:  73.83 and 0.0 respectively
# At random state of :-  99 the root mean squared error of Testing and Training are:  8.59 and 0.0 respectively
#
#
# At random state of :- 100 Testing Accuracy and Training Accuracy are:  -1.69 and 100.0 respectively
# At random state of :-  100 the mean absolute error of Testing and Training are:  6.13 and 0.0 respectively
# At random state of :-  100 the mean squared error of Testing and Training are:  56.07 and 0.0 respectively
# At random state of :-  100 the root mean squared error of Testing and Training are:  7.49 and 0.0 respectively
#
#
# At random state of :- 101 Testing Accuracy and Training Accuracy are:  8.9 and 100.0 respectively
# At random state of :-  101 the mean absolute error of Testing and Training are:  4.4 and 0.0 respectively
# At random state of :-  101 the mean squared error of Testing and Training are:  36.34 and 0.0 respectively
# At random state of :-  101 the root mean squared error of Testing and Training are:  6.03 and 0.0 respectively
#
#
# At random state of :- 102 Testing Accuracy and Training Accuracy are:  21.96 and 100.0 respectively
# At random state of :-  102 the mean absolute error of Testing and Training are:  7.23 and 0.0 respectively
# At random state of :-  102 the mean squared error of Testing and Training are:  63.67 and 0.0 respectively
# At random state of :-  102 the root mean squared error of Testing and Training are:  7.98 and 0.0 respectively
#
#
# At random state of :- 103 Testing Accuracy and Training Accuracy are:  24.52 and 100.0 respectively
# At random state of :-  103 the mean absolute error of Testing and Training are:  6.9 and 0.0 respectively
# At random state of :-  103 the mean squared error of Testing and Training are:  75.15 and 0.0 respectively
# At random state of :-  103 the root mean squared error of Testing and Training are:  8.67 and 0.0 respectively
#
#
# At random state of :- 104 Testing Accuracy and Training Accuracy are:  41.8 and 100.0 respectively
# At random state of :-  104 the mean absolute error of Testing and Training are:  7.48 and 0.0 respectively
# At random state of :-  104 the mean squared error of Testing and Training are:  72.5 and 0.0 respectively
# At random state of :-  104 the root mean squared error of Testing and Training are:  8.51 and 0.0 respectively
#
#
# At random state of :- 105 Testing Accuracy and Training Accuracy are:  -388.66 and 100.0 respectively
# At random state of :-  105 the mean absolute error of Testing and Training are:  5.9 and 0.0 respectively
# At random state of :-  105 the mean squared error of Testing and Training are:  47.24 and 0.0 respectively
# At random state of :-  105 the root mean squared error of Testing and Training are:  6.87 and 0.0 respectively
#
#
# At random state of :- 106 Testing Accuracy and Training Accuracy are:  41.68 and 100.0 respectively
# At random state of :-  106 the mean absolute error of Testing and Training are:  8.71 and 0.0 respectively
# At random state of :-  106 the mean squared error of Testing and Training are:  97.58 and 0.0 respectively
# At random state of :-  106 the root mean squared error of Testing and Training are:  9.88 and 0.0 respectively
#
#
# At random state of :- 107 Testing Accuracy and Training Accuracy are:  -65.55 and 100.0 respectively
# At random state of :-  107 the mean absolute error of Testing and Training are:  6.71 and 0.0 respectively
# At random state of :-  107 the mean squared error of Testing and Training are:  67.14 and 0.0 respectively
# At random state of :-  107 the root mean squared error of Testing and Training are:  8.19 and 0.0 respectively
#
#
# At random state of :- 108 Testing Accuracy and Training Accuracy are:  68.65 and 100.0 respectively
# At random state of :-  108 the mean absolute error of Testing and Training are:  5.39 and 0.0 respectively
# At random state of :-  108 the mean squared error of Testing and Training are:  40.8 and 0.0 respectively
# At random state of :-  108 the root mean squared error of Testing and Training are:  6.39 and 0.0 respectively
#
#
# At random state of :- 109 Testing Accuracy and Training Accuracy are:  -100.31 and 100.0 respectively
# At random state of :-  109 the mean absolute error of Testing and Training are:  5.08 and 0.0 respectively
# At random state of :-  109 the mean squared error of Testing and Training are:  39.84 and 0.0 respectively
# At random state of :-  109 the root mean squared error of Testing and Training are:  6.31 and 0.0 respectively
#
#
# At random state of :- 110 Testing Accuracy and Training Accuracy are:  48.53 and 100.0 respectively
# At random state of :-  110 the mean absolute error of Testing and Training are:  3.58 and 0.0 respectively
# At random state of :-  110 the mean squared error of Testing and Training are:  21.1 and 0.0 respectively
# At random state of :-  110 the root mean squared error of Testing and Training are:  4.59 and 0.0 respectively
#
#
# At random state of :- 111 Testing Accuracy and Training Accuracy are:  28.92 and 100.0 respectively
# At random state of :-  111 the mean absolute error of Testing and Training are:  9.43 and 0.0 respectively
# At random state of :-  111 the mean squared error of Testing and Training are:  101.81 and 0.0 respectively
# At random state of :-  111 the root mean squared error of Testing and Training are:  10.09 and 0.0 respectively
#
#
# At random state of :- 112 Testing Accuracy and Training Accuracy are:  18.05 and 100.0 respectively
# At random state of :-  112 the mean absolute error of Testing and Training are:  4.28 and 0.0 respectively
# At random state of :-  112 the mean squared error of Testing and Training are:  40.07 and 0.0 respectively
# At random state of :-  112 the root mean squared error of Testing and Training are:  6.33 and 0.0 respectively
#
#
# At random state of :- 113 Testing Accuracy and Training Accuracy are:  52.33 and 100.0 respectively
# At random state of :-  113 the mean absolute error of Testing and Training are:  5.51 and 0.0 respectively
# ...
# At random state of :-  162 the root mean squared error of Testing and Training are:  7.04 and 0.0 respectively
#
#
# At random state of :- 163 Testing Accuracy and Training Accuracy are:  56.78 and 100.0 respectively
# At random state of :-  163 the mean absolute error of Testing and Training are:  5.53 and 0.0 respectively
# At random state of :-  163 the mean squared error of Testing and Training are:  38.38 and 0.0 respectively
# At random state of :-  163 the root mean squared error of Testing and Training are:  6.2 and 0.0 respectively
#
#
# At random state of :- 164 Testing Accuracy and Training Accuracy are:  -18.46 and 100.0 respectively
# At random state of :-  164 the mean absolute error of Testing and Training are:  7.6 and 0.0 respectively
# At random state of :-  164 the mean squared error of Testing and Training are:  99.77 and 0.0 respectively
# At random state of :-  164 the root mean squared error of Testing and Training are:  9.99 and 0.0 respectively
#
#
# At random state of :- 165 Testing Accuracy and Training Accuracy are:  41.9 and 100.0 respectively
# At random state of :-  165 the mean absolute error of Testing and Training are:  7.46 and 0.0 respectively
# At random state of :-  165 the mean squared error of Testing and Training are:  68.69 and 0.0 respectively
# At random state of :-  165 the root mean squared error of Testing and Training are:  8.29 and 0.0 respectively
#
#
# At random state of :- 166 Testing Accuracy and Training Accuracy are:  27.29 and 100.0 respectively
# At random state of :-  166 the mean absolute error of Testing and Training are:  5.62 and 0.0 respectively
# At random state of :-  166 the mean squared error of Testing and Training are:  46.94 and 0.0 respectively
# At random state of :-  166 the root mean squared error of Testing and Training are:  6.85 and 0.0 respectively
#
#
# At random state of :- 167 Testing Accuracy and Training Accuracy are:  -11.38 and 100.0 respectively
# At random state of :-  167 the mean absolute error of Testing and Training are:  8.51 and 0.0 respectively
# At random state of :-  167 the mean squared error of Testing and Training are:  107.3 and 0.0 respectively
# At random state of :-  167 the root mean squared error of Testing and Training are:  10.36 and 0.0 respectively
#
#
# At random state of :- 168 Testing Accuracy and Training Accuracy are:  37.88 and 100.0 respectively
# At random state of :-  168 the mean absolute error of Testing and Training are:  6.86 and 0.0 respectively
# At random state of :-  168 the mean squared error of Testing and Training are:  61.58 and 0.0 respectively
# At random state of :-  168 the root mean squared error of Testing and Training are:  7.85 and 0.0 respectively
#
#
# At random state of :- 169 Testing Accuracy and Training Accuracy are:  14.38 and 100.0 respectively
# At random state of :-  169 the mean absolute error of Testing and Training are:  8.18 and 0.0 respectively
# At random state of :-  169 the mean squared error of Testing and Training are:  94.01 and 0.0 respectively
# At random state of :-  169 the root mean squared error of Testing and Training are:  9.7 and 0.0 respectively
#
#
# At random state of :- 170 Testing Accuracy and Training Accuracy are:  43.06 and 100.0 respectively
# At random state of :-  170 the mean absolute error of Testing and Training are:  4.0 and 0.0 respectively
# At random state of :-  170 the mean squared error of Testing and Training are:  31.08 and 0.0 respectively
# At random state of :-  170 the root mean squared error of Testing and Training are:  5.58 and 0.0 respectively
#
#
# At random state of :- 171 Testing Accuracy and Training Accuracy are:  64.06 and 100.0 respectively
# At random state of :-  171 the mean absolute error of Testing and Training are:  4.57 and 0.0 respectively
# At random state of :-  171 the mean squared error of Testing and Training are:  33.35 and 0.0 respectively
# At random state of :-  171 the root mean squared error of Testing and Training are:  5.77 and 0.0 respectively
#
#
# At random state of :- 172 Testing Accuracy and Training Accuracy are:  7.35 and 100.0 respectively
# At random state of :-  172 the mean absolute error of Testing and Training are:  4.69 and 0.0 respectively
# At random state of :-  172 the mean squared error of Testing and Training are:  47.07 and 0.0 respectively
# At random state of :-  172 the root mean squared error of Testing and Training are:  6.86 and 0.0 respectively
#
#
# At random state of :- 173 Testing Accuracy and Training Accuracy are:  48.26 and 100.0 respectively
# At random state of :-  173 the mean absolute error of Testing and Training are:  8.93 and 0.0 respectively
# At random state of :-  173 the mean squared error of Testing and Training are:  100.84 and 0.0 respectively
# At random state of :-  173 the root mean squared error of Testing and Training are:  10.04 and 0.0 respectively
#
#
# At random state of :- 174 Testing Accuracy and Training Accuracy are:  22.02 and 100.0 respectively
# At random state of :-  174 the mean absolute error of Testing and Training are:  6.63 and 0.0 respectively
# At random state of :-  174 the mean squared error of Testing and Training are:  63.86 and 0.0 respectively
# At random state of :-  174 the root mean squared error of Testing and Training are:  7.99 and 0.0 respectively
#
#
# At random state of :- 175 Testing Accuracy and Training Accuracy are:  23.34 and 100.0 respectively
# At random state of :-  175 the mean absolute error of Testing and Training are:  7.34 and 0.0 respectively
# At random state of :-  175 the mean squared error of Testing and Training are:  91.39 and 0.0 respectively
# At random state of :-  175 the root mean squared error of Testing and Training are:  9.56 and 0.0 respectively
#
#
# At random state of :- 176 Testing Accuracy and Training Accuracy are:  59.67 and 100.0 respectively
# At random state of :-  176 the mean absolute error of Testing and Training are:  4.98 and 0.0 respectively
# At random state of :-  176 the mean squared error of Testing and Training are:  35.15 and 0.0 respectively
# At random state of :-  176 the root mean squared error of Testing and Training are:  5.93 and 0.0 respectively
#
#
# At random state of :- 177 Testing Accuracy and Training Accuracy are:  -7.49 and 100.0 respectively
# At random state of :-  177 the mean absolute error of Testing and Training are:  5.94 and 0.0 respectively
# At random state of :-  177 the mean squared error of Testing and Training are:  41.56 and 0.0 respectively
# At random state of :-  177 the root mean squared error of Testing and Training are:  6.45 and 0.0 respectively
#
#
# At random state of :- 178 Testing Accuracy and Training Accuracy are:  57.65 and 100.0 respectively
# At random state of :-  178 the mean absolute error of Testing and Training are:  5.63 and 0.0 respectively
# At random state of :-  178 the mean squared error of Testing and Training are:  43.99 and 0.0 respectively
# At random state of :-  178 the root mean squared error of Testing and Training are:  6.63 and 0.0 respectively
#
#
# At random state of :- 179 Testing Accuracy and Training Accuracy are:  40.18 and 100.0 respectively
# At random state of :-  179 the mean absolute error of Testing and Training are:  5.65 and 0.0 respectively
# At random state of :-  179 the mean squared error of Testing and Training are:  51.2 and 0.0 respectively
# At random state of :-  179 the root mean squared error of Testing and Training are:  7.16 and 0.0 respectively
#
#
# At random state of :- 180 Testing Accuracy and Training Accuracy are:  31.81 and 100.0 respectively
# At random state of :-  180 the mean absolute error of Testing and Training are:  5.17 and 0.0 respectively
# At random state of :-  180 the mean squared error of Testing and Training are:  44.25 and 0.0 respectively
# At random state of :-  180 the root mean squared error of Testing and Training are:  6.65 and 0.0 respectively
#
#
# At random state of :- 181 Testing Accuracy and Training Accuracy are:  62.34 and 100.0 respectively
# At random state of :-  181 the mean absolute error of Testing and Training are:  4.33 and 0.0 respectively
# At random state of :-  181 the mean squared error of Testing and Training are:  28.92 and 0.0 respectively
# At random state of :-  181 the root mean squared error of Testing and Training are:  5.38 and 0.0 respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:  26.74 and 100.0 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:  7.98 and 0.0 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:  85.15 and 0.0 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:  9.23 and 0.0 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:  46.6 and 100.0 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:  5.22 and 0.0 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:  39.3 and 0.0 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:  6.27 and 0.0 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:  60.87 and 100.0 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:  5.73 and 0.0 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:  37.53 and 0.0 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:  6.13 and 0.0 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:  -47.51 and 100.0 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:  8.08 and 0.0 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:  85.39 and 0.0 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:  9.24 and 0.0 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:  55.86 and 100.0 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:  4.34 and 0.0 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:  29.38 and 0.0 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:  5.42 and 0.0 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:  -47.98 and 100.0 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:  6.99 and 0.0 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:  64.45 and 0.0 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:  8.03 and 0.0 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:  40.71 and 100.0 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:  4.48 and 0.0 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:  40.8 and 0.0 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:  6.39 and 0.0 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:  48.2 and 100.0 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:  9.65 and 0.0 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:  111.61 and 0.0 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:  10.56 and 0.0 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:  55.39 and 100.0 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:  5.1 and 0.0 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:  52.74 and 0.0 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:  7.26 and 0.0 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:  48.24 and 100.0 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:  6.1 and 0.0 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:  42.56 and 0.0 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:  6.52 and 0.0 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:  47.75 and 100.0 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:  6.27 and 0.0 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:  49.18 and 0.0 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:  7.01 and 0.0 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:  -149.58 and 100.0 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:  5.53 and 0.0 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:  40.28 and 0.0 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:  6.35 and 0.0 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:  60.81 and 100.0 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:  7.54 and 0.0 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:  64.25 and 0.0 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:  8.02 and 0.0 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:  46.98 and 100.0 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:  8.26 and 0.0 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:  105.09 and 0.0 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:  10.25 and 0.0 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:  64.97 and 100.0 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:  5.16 and 0.0 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:  38.85 and 0.0 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:  6.23 and 0.0 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:  27.95 and 100.0 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:  6.21 and 0.0 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:  50.67 and 0.0 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:  7.12 and 0.0 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:  53.2 and 100.0 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:  5.99 and 0.0 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:  66.41 and 0.0 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:  8.15 and 0.0 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:  -29.76 and 100.0 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:  8.35 and 0.0 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:  104.57 and 0.0 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:  10.23 and 0.0 respectively

# %% [markdown]
# The best accuracy is 83.83% at random state 82

# %% [markdown]
# We have found best_random state value as 82. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=82,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
ex=ExtraTreesRegressor()#Initializing...
ex.fit(x_train,y_train)#Training...
pred_test=ex.predict(x_test)#Prediciting using test data...
pred_train=ex.predict(x_train)#Prediciting using training data...
Test_Accuracy_ex= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_ex= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_ex= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_ex= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_ex= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_ex= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_ex= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_ex= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_ex)#printing mean absolute error
print("Test_MSE ", Test_mse_ex)#printing mean squared error
print("Test_RMSE ", Test_rmse_ex)#printing root mean squared error
# Out:
# Test_Accuracy  83.37
# Test_MAE  2.6700000000000017
# Test_MSE  12.166433333333345
# Test_RMSE  3.4880414752885818

# %% [markdown]
# ExtraTress  is producing good accuracy = 83.37%. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation of accuracy
vac=cross_val_score(ex,X,Y,cv=5)
CV_Score_ex=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_ex)
# Out:
# [ 0.10447034 -2.89803421  0.39219155  0.12673213  0.72729776]
# Cross Validation Score is  -0.3094684854767381

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_ex
# Out:
# 0.8336530193695403

# %%
CV_Score_ex
# Out:
# -0.3094684854767381

# %%
ex_Acc_vs_CV_Score=np.abs(Test_Accuracy_ex-CV_Score_ex)
print("Difference between Accuracy and Cross Validation Score = ",ex_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.1431215048462784

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is low (1.14) meaning that model is not having any overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
#  Now that we have build 7 models in total lets compare each of them and find the best Model!

# %% [markdown]
# # Step 6 - COMPARING ALL EIGHT MACHINE LEARNING MODELS

# %% [markdown]
# # Step 6.1 - Creating a Dataframe for Accuracy Comparison

# %% [markdown]
# Lets create a dataframe that will juxtapose the metrics of all the models...

# %%
#Constructing a dataframe...
models = pd.DataFrame({'ML_Model' : ['Linear Regression','Decision Tree Regressor','Random Forest Regressor','Ada Boosting Regressor','Gradient Boosting Regressor', 'XgBoost','Extra Trees Regressor'],'Accuracy_Score' : [Test_Accuracy_lm,Test_Accuracy_dt,Test_Accuracy_rf,Test_Accuracy_ada,Test_Accuracy_gb,Test_Accuracy_xgb,Test_Accuracy_ex],'Cross_Validation_Score':[CV_Score_lm,CV_Score_dt,CV_Score_rf,CV_Score_ada,CV_Score_gb,CV_Score_xgb,CV_Score_ex],'Accuracy_VS_CVScore':[lm_Acc_vs_CV_Score,dt_Acc_vs_CV_Score,rf_Acc_vs_CV_Score,ada_Acc_vs_CV_Score,gb_Acc_vs_CV_Score,xgb_Acc_vs_CV_Score,ex_Acc_vs_CV_Score],'MAE':[Test_mae_lm,Test_mae_dt,Test_mae_rf,Test_mae_ada,Test_mae_gb,Test_mae_xgb,Test_mae_ex],'MSE':[Test_mse_lm,Test_mse_dt,Test_mse_rf,Test_mse_ada,Test_mse_gb,Test_mse_xgb,Test_mse_ex],'RMSE':[Test_rmse_lm,Test_rmse_dt,Test_rmse_rf,Test_rmse_ada,Test_rmse_gb,Test_rmse_xgb,Test_rmse_ex]})
models
# Out:
#                       ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 0            Linear Regression        0.926553               -0.203458
# 1      Decision Tree Regressor        0.822645               -0.792623
# 2      Random Forest Regressor        0.813001               -0.540717
# 3       Ada Boosting Regressor        0.814838               -0.698129
# 4  Gradient Boosting Regressor        0.837362               -0.652277
# 5                      XgBoost        0.869370               -0.847043
# 6        Extra Trees Regressor        0.833653               -0.309468
#
#    Accuracy_VS_CVScore       MAE        MSE      RMSE
# 0             1.130011  2.282049   5.622771  2.371238
# 1             1.615268  3.666667  19.666667  4.434712
# 2             1.353718  4.260000  25.520233  5.051755
# 3             1.512966  3.684524  14.360379  3.789509
# 4             1.489639  3.371415  12.613479  3.551546
# 5             1.716412  2.871073  10.131111  3.182941
# 6             1.143122  2.670000  12.166433  3.488041

# %%
#Converting Accuracy and Cross_Validation_Score into Percentage....
models["Accuracy_Score"] = (models["Accuracy_Score"] * 100).round(2)
models["Cross_Validation_Score"] = (models["Cross_Validation_Score"] * 100).round(2)
models.sort_values(by = 'Accuracy_Score', ascending = False)
# Out:
#                       ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 0            Linear Regression           92.66                  -20.35
# 5                      XgBoost           86.94                  -84.70
# 4  Gradient Boosting Regressor           83.74                  -65.23
# 6        Extra Trees Regressor           83.37                  -30.95
# 1      Decision Tree Regressor           82.26                  -79.26
# 3       Ada Boosting Regressor           81.48                  -69.81
# 2      Random Forest Regressor           81.30                  -54.07
#
#    Accuracy_VS_CVScore       MAE        MSE      RMSE
# 0             1.130011  2.282049   5.622771  2.371238
# 5             1.716412  2.871073  10.131111  3.182941
# 4             1.489639  3.371415  12.613479  3.551546
# 6             1.143122  2.670000  12.166433  3.488041
# 1             1.615268  3.666667  19.666667  4.434712
# 3             1.512966  3.684524  14.360379  3.789509
# 2             1.353718  4.260000  25.520233  5.051755

# %%
#Now focusing on the Accuracy Score....
plt.figure(figsize = (10, 5))
sns.set_style('darkgrid')

sns.barplot(x = 'Accuracy_Score', y = 'ML_Model', data = models)

plt.xlabel('Accuracy Score in %', fontsize = 15)
plt.ylabel('ML Model', fontsize = 15)

plt.title('ML Model Comparison', fontsize = 16)

plt.show()

# %% [markdown]
# Now from the above diagram it seems that Linear Regrression(92.66%) has the highest Accuracy, However, our aim is to find the BEST MODEL, so lets consider the difference Between Accuracy_Score and Cross_Validation_Score....

# %% [markdown]
# # Step 6.2 - Comparing Differences between Accuracy and Cross_Validation Scores...

# %% [markdown]
# Lets sort by the column; Accuracy_VS_CVScore to have a good view of the differential between Accuracy_Score and CVScore

# %%
#Sorting....
models.sort_values(by = 'Accuracy_VS_CVScore', ascending = True)
# Out:
#                       ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 0            Linear Regression           92.66                  -20.35
# 6        Extra Trees Regressor           83.37                  -30.95
# 2      Random Forest Regressor           81.30                  -54.07
# 4  Gradient Boosting Regressor           83.74                  -65.23
# 3       Ada Boosting Regressor           81.48                  -69.81
# 1      Decision Tree Regressor           82.26                  -79.26
# 5                      XgBoost           86.94                  -84.70
#
#    Accuracy_VS_CVScore       MAE        MSE      RMSE
# 0             1.130011  2.282049   5.622771  2.371238
# 6             1.143122  2.670000  12.166433  3.488041
# 2             1.353718  4.260000  25.520233  5.051755
# 4             1.489639  3.371415  12.613479  3.551546
# 3             1.512966  3.684524  14.360379  3.789509
# 1             1.615268  3.666667  19.666667  4.434712
# 5             1.716412  2.871073  10.131111  3.182941

# %%
#A more clearer visualization.....
plt.figure(figsize = (10, 5))
sns.set_style('darkgrid')

sns.barplot(x = 'Accuracy_VS_CVScore', y = 'ML_Model', data = models)

plt.xlabel('Difference btw Accuracy Score and Cross_Validation Score ', fontsize = 15)
plt.ylabel('ML Model', fontsize = 15)

plt.title('Accuracy VS CVScore Comparison', fontsize = 16)

plt.show()

# %% [markdown]
# # From the above we can see the Model with least difference is Still LINEAR REGRESSION!

# %% [markdown]
# # Step 6.3 - Conclusion on Best Choice of Model

# %% [markdown]
# From the above we can see:
#  - The Model with least difference(1.13) between Accuracy Score(r2 score) and Cross Validation Score is LINEAR REGRESSION!
#
#  - It has a Root Mean Square Error(RMSE): 2.37

# %%
#Checking the parameters
x_train_sm = sm.add_constant(x_train)
lm = sm.OLS(y_train,x_train_sm).fit()
lm.params
# Out:
# const    79.634504
# x1        5.687222
# x2       -1.571366
# x3       -0.937697
# x4        1.830353
# x5       -0.098621
# x6       -0.573730
# x7        1.479630
# x8       -0.890054
# x9        1.101919
# x10       0.151452
# x11       4.050213
# x12       6.796269
# x13       1.186975
# dtype: float64

# %%
#Now lets the the OLS Regression result
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     7.684
# Date:                Wed, 05 Oct 2022   Prob (F-statistic):            0.00220
# Time:                        19:10:23   Log-Likelihood:                -59.175
# No. Observations:                  23   AIC:                             146.4
# Df Residuals:                       9   BIC:                             162.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         79.6345      1.185     67.196      0.000      76.954      82.315
# x1             5.6872      2.392      2.378      0.041       0.276      11.098
# x2            -1.5714      2.513     -0.625      0.547      -7.257       4.114
# x3            -0.9377      3.122     -0.300      0.771      -8.001       6.126
# x4             1.8304      1.787      1.024      0.333      -2.213       5.873
# x5            -0.0986      1.634     -0.060      0.953      -3.794       3.597
# x6            -0.5737      2.467     -0.233      0.821      -6.155       5.008
# x7             1.4796      1.963      0.754      0.470      -2.961       5.920
# x8            -0.8901      1.629     -0.546      0.598      -4.576       2.796
# x9             1.1019      1.500      0.735      0.481      -2.291       4.495
# x10            0.1515      2.230      0.068      0.947      -4.894       5.197
# x11            4.0502      1.408      2.877      0.018       0.866       7.235
# x12            6.7963      1.498      4.537      0.001       3.408      10.185
# x13            1.1870      1.989      0.597      0.565      -3.312       5.686
# ==============================================================================
# Omnibus:                        6.803   Durbin-Watson:                   1.556
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                4.558
# Skew:                          -0.876   Prob(JB):                        0.102
# Kurtosis:                       4.298   Cond. No.                         8.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Hence Optimum Machine Model Chosen = LINEAR REGRESSION MODEL!

# %% [markdown]
# # Step 7 - HYPERPARAMETER TUNNING
#
#
#  - SInce Accurracy is 93%, there won't be any need for Tunning as Accuracy is very Good!

# %% [markdown]
# # Step 8 - MODEL SAVING

# %%
filename='Machine_Model_Project_Baseball'
pickle.dump(lm,open(filename,'wb'))
